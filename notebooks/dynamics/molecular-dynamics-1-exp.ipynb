# %% [markdown]
# # Molecular Dynamics: Stability
#
# Before continue, you should have:
#
# - installed GROMACS
# - put CHARMM36 force field in the correct location
# - generated a backbone structure
# - predicted the sequence of the generated structure
# - modelled and added side chains to the structure
# - added H atoms to the structure

# %%
import os

os.environ['PATH'] = '/usr/local/gromacs/bin:' + os.environ['PATH']

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

# %%
PROTEIN_CLS = "GFP"
PROTEIN_SID = "3W1C_A"
assert PROTEIN_CLS is not None
assert PROTEIN_SID is not None
PROTEIN_PDB = Path(f"../../data/{PROTEIN_CLS}/processed/{PROTEIN_SID}.pdb")

# Create a new working directory!
WD = Path(f"wd-md1/{PROTEIN_CLS}/{PROTEIN_SID}")
WD.mkdir(parents=True, exist_ok=True)

# TOOLS: Change the path accordingly
GROMACS_PATH = "~/WS/ProtMatch/gromacs"

# %% [markdown]
# Cleaning the input structure
#
# Strip out all the atoms that do not belong to the protein (e.i crystal waters, ligands, etc).

# %%
PROTEIN_TMP = Path(f"{PROTEIN_PDB.name}_tmp.pdb")
# !grep -v HETATM {PROTEIN_PDB} > {WD}/{PROTEIN_TMP}

PROTEIN_PDB = Path(PROTEIN_PDB.name)
# !cd {WD} && grep -v CONECT {PROTEIN_TMP} > {PROTEIN_PDB}

# !cd {WD} && rm -f {PROTEIN_TMP}
del PROTEIN_TMP

# %% [markdown]
# Move the protein to the origin.

# %%
PROTEIN_TMP = Path(f"{PROTEIN_PDB.stem}.pdb")
# !cd {WD} && vmd -dispdev text -eofexit -args < {GROMACS_PATH}/to_origin.tcl {PROTEIN_PDB} {PROTEIN_TMP}
PROTEIN_PDB = PROTEIN_TMP
del PROTEIN_TMP
# Out:
# Info) VMD for LINUXAMD64, version 1.9.4a57 (April 27, 2022)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 24 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info)   Detected VM or hypervisor execution environment
# Info) Free system memory: 30GB (95%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Unable to load NVML library, GPU-CPU affinity unavailable.
# Info) Detected 1 available CUDA accelerator::
# Info) [0] NVIDIA GeForce RTX 4090 128 SM_8.9 2.6 GHz, 24GB RAM SP64 KT AE1 ZC
# OptiXRenderer) ERROR: Failed to load OptiX shared library.
# OptiXRenderer)        NVIDIA driver may be too old.
# OptiXRenderer)        Check/update NVIDIA driver
# Info) Dynamically loaded 3 plugins in directory:
# Info) /usr/local/lib/vmd/plugins/LINUXAMD64/molfile
# 3W1C_A.pdb
# Info) Using plugin pdb for structure file 3W1C_A.pdb
# Info) Using plugin pdb for coordinates from file 3W1C_A.pdb
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file 3W1C_A.pdb.
# Info) Analyzing structure ...
# Info)    Atoms: 1813
# Info)    Bonds: 1855
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 228
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 2   Protein: 2   Nucleic: 0
# 0
# atomselect0
# invalid command name "vectinvert"
# Info) Opened coordinate file 3W1C_A.pdb for writing.
# Info) Finished with coordinate file 3W1C_A.pdb.
# Info) VMD for LINUXAMD64, version 1.9.4a57 (April 27, 2022)
# Info) Exiting normally.

# %% [markdown]
# ## Setting Up the Simulation Box and Converting File Format
#
# - Distance between the solute and the box: 15 nm
# - Box type: octahedron
# - Center molecule in box.

# %%
PROTEIN_GRO = Path(f"{PROTEIN_PDB.stem}.gro")
# !cd {WD} && gmx editconf -f {PROTEIN_PDB} -o {PROTEIN_GRO} -c -d 1.5 -bt octahedron
# Out:
#                      :-) GROMACS - gmx editconf, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx editconf -f 3W1C_A.pdb -o 3W1C_A.gro -c -d 1.5 -bt octahedron
#
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 1813 atoms
# Volume: 0 nm^3, corresponds to roughly 0 electrons
# No velocities found
#     system size :  4.315  5.060  5.392 (nm)
#     diameter    :  5.470               (nm)
#     center      : -0.067 -0.282  0.368 (nm)
#     box vectors :  0.000  0.000  0.000 (nm)
#     box angles  :   0.00   0.00   0.00 (degrees)
#     box volume  :   0.00               (nm^3)
#     shift       :  4.302  6.271  3.090 (nm)
# new center      :  4.235  5.989  3.458 (nm)
# new box vectors :  8.470  8.470  8.470 (nm)
# new box angles  :  70.53 109.47  70.53 (degrees)
# new box volume  : 467.79               (nm^3)
#
# GROMACS reminds you: "A university faculty is 500 egotists with a common parking problem." (Keith Sullivan)

# %% [markdown]
# ## Generating Topology with CHARMM36 Force Field
#
# Generate the topology for the protein structure using the **charmm36** force field and the **TIP3P** water model.
# The topology file defines the molecular structure, including atomic types, charges, and bonding information, which is essential for subsequent molecular dynamics simulations.
#
# > (From GROMACS 2024 Manual)
# > CHARMM (Chemistry at HARvard Macromolecular Mechanics) is a both a set of force fields and a software package for molecular dynamics (page 328) simulations and analysis. Includes united atom (CHARMM19) and all atom (CHARMM22, CHARMM27, CHARMM36) force fields (page 328). The CHARMM27 force field has been ported to GROMACS and is officially supported. CHARMM36 force field files can be obtained from the MacKerell lab website, which regularly produces up-to-date CHARMM force field files in GROMACS format.
# >
# > For using CHARMM36 in GROMACS, please use the following settings in the mdp (page 483) file:
# > ```
# > constraints = h-bonds
# > cutoff-scheme = Verlet
# > vdwtype = cutoff
# > vdw-modifier = force-switch
# > rlist = 1.2
# > rvdw = 1.2
# > rvdw-switch = 1.0
# > coulombtype = PME
# > rcoulomb = 1.2
# > DispCorr = no
# > ```
# > Note that dispersion correction should be applied in the case of lipid monolayers, but not bilayers.
# > Please also note that the switching distance is a matter of some debate in lipid bilayer simulations, and it is dependent to some extent on the nature of the lipid. Some studies have found that an 0.8-1.0 nm switch is appropriate, others argue 0.8-1.2 nm is best, and yet others stand by 1.0-1.2 nm. The user is cautioned to thoroughly investigate the force field literature for their chosen lipid(s) before beginning a simulation!

# %%
PROTEIN_TOP_GRO = Path(f"{PROTEIN_PDB.stem}_top.gro")
PROTEIN_TOP = Path(f"{PROTEIN_PDB.stem}.top")
FF_PATH = Path("../../gromacs/charmm36-jul2022.ff")
# !cp -r {FF_PATH} {WD}
# !cd {WD} && gmx pdb2gmx -f {PROTEIN_GRO} -o {PROTEIN_TOP_GRO} -p {PROTEIN_TOP} -water tip3p -ff charmm36-jul2022
# Any errors check https://manual.gromacs.org/2021.4/user-guide/run-time-errors.html.
# If a fatal error occurred due to H, this atom may not defined in the FF.
# Consider to remove this atom from PDB, or (not recommended) ignore hydrogen atoms with `-ignh`.
# If atom C1 not found in buiding block 1MET while combining tdb and rtp, you may need `-ter`.
# Check more at https://gromacs.bioexcel.eu/t/newest-charmm36-port-for-gromacs/868/11.
# !cd {WD} && echo "1 0" | gmx pdb2gmx -f {PROTEIN_GRO} -o {PROTEIN_TOP_GRO} -p {PROTEIN_TOP} -water tip3p -ff charmm36-jul2022 -ignh -ter
# !cd {WD} && gmx pdb2gmx -f {PROTEIN_GRO} -o {PROTEIN_TOP_GRO} -p {PROTEIN_TOP} -water tip3p -ff charmm36-jul2022 -ignh
# Out:
#                      :-) GROMACS - gmx pdb2gmx, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx pdb2gmx -f 3W1C_A.gro -o 3W1C_A_top.gro -p 3W1C_A.top -water tip3p -ff charmm36-jul2022 -ignh
#
# Using the Charmm36-jul2022 force field in directory ./charmm36-jul2022.ff
#
# going to rename ./charmm36-jul2022.ff/aminoacids.r2b
# Opening force field file ./charmm36-jul2022.ff/aminoacids.r2b
#
# going to rename ./charmm36-jul2022.ff/carb.r2b
# Opening force field file ./charmm36-jul2022.ff/carb.r2b
#
# going to rename ./charmm36-jul2022.ff/cgenff.r2b
# Opening force field file ./charmm36-jul2022.ff/cgenff.r2b
#
# going to rename ./charmm36-jul2022.ff/ethers.r2b
# Opening force field file ./charmm36-jul2022.ff/ethers.r2b
#
# going to rename ./charmm36-jul2022.ff/lipid.r2b
# Opening force field file ./charmm36-jul2022.ff/lipid.r2b
#
# going to rename ./charmm36-jul2022.ff/metals.r2b
# Opening force field file ./charmm36-jul2022.ff/metals.r2b
#
# going to rename ./charmm36-jul2022.ff/na.r2b
# Opening force field file ./charmm36-jul2022.ff/na.r2b
#
# going to rename ./charmm36-jul2022.ff/silicates.r2b
# Opening force field file ./charmm36-jul2022.ff/silicates.r2b
#
# going to rename ./charmm36-jul2022.ff/solvent.r2b
# Opening force field file ./charmm36-jul2022.ff/solvent.r2b
# Reading 3W1C_A.gro...
# Read 'Guyana Rwanda Oman Macau Angola Cameroon Senegal', 1813 atoms
#
# Analyzing pdb file
# Splitting chemical chains based on TER records or chain id changing.
#
# There are 1 chains and 0 blocks of water and 228 residues with 1813 atoms
#
#   chain  #res #atoms
#
#   1 ' '   228   1813
#
# No occupancies in 3W1C_A.gro
# No occupancies in 3W1C_A.gro
# Opening force field file ./charmm36-jul2022.ff/atomtypes.atp
#
# Reading residue database... (Charmm36-jul2022)
# Opening force field file ./charmm36-jul2022.ff/aminoacids.rtp
# Opening force field file ./charmm36-jul2022.ff/carb.rtp
# Opening force field file ./charmm36-jul2022.ff/cgenff.rtp
# Opening force field file ./charmm36-jul2022.ff/ethers.rtp
# Opening force field file ./charmm36-jul2022.ff/lipid.rtp
# Opening force field file ./charmm36-jul2022.ff/metals.rtp
# Opening force field file ./charmm36-jul2022.ff/na.rtp
# Opening force field file ./charmm36-jul2022.ff/silicates.rtp
# Opening force field file ./charmm36-jul2022.ff/solvent.rtp
# Opening force field file ./charmm36-jul2022.ff/aminoacids.hdb
# Opening force field file ./charmm36-jul2022.ff/carb.hdb
# Opening force field file ./charmm36-jul2022.ff/cgenff.hdb
# Opening force field file ./charmm36-jul2022.ff/ethers.hdb
# Opening force field file ./charmm36-jul2022.ff/lipid.hdb
# Opening force field file ./charmm36-jul2022.ff/metals.hdb
# Opening force field file ./charmm36-jul2022.ff/na.hdb
# Opening force field file ./charmm36-jul2022.ff/silicates.hdb
# Opening force field file ./charmm36-jul2022.ff/solvent.hdb
# Opening force field file ./charmm36-jul2022.ff/aminoacids.n.tdb
# Opening force field file ./charmm36-jul2022.ff/carb.n.tdb
# Opening force field file ./charmm36-jul2022.ff/cgenff.n.tdb
# Opening force field file ./charmm36-jul2022.ff/ethers.n.tdb
# Opening force field file ./charmm36-jul2022.ff/lipid.n.tdb
# Opening force field file ./charmm36-jul2022.ff/metals.n.tdb
# Opening force field file ./charmm36-jul2022.ff/na.n.tdb
# Opening force field file ./charmm36-jul2022.ff/silicates.n.tdb
# Opening force field file ./charmm36-jul2022.ff/solvent.n.tdb
# Opening force field file ./charmm36-jul2022.ff/aminoacids.c.tdb
# Opening force field file ./charmm36-jul2022.ff/carb.c.tdb
# Opening force field file ./charmm36-jul2022.ff/cgenff.c.tdb
# Opening force field file ./charmm36-jul2022.ff/ethers.c.tdb
# Opening force field file ./charmm36-jul2022.ff/lipid.c.tdb
# Opening force field file ./charmm36-jul2022.ff/metals.c.tdb
# Opening force field file ./charmm36-jul2022.ff/na.c.tdb
# Opening force field file ./charmm36-jul2022.ff/silicates.c.tdb
# Opening force field file ./charmm36-jul2022.ff/solvent.c.tdb
#
# Processing chain 1 (1813 atoms, 228 residues)
# Analysing hydrogen-bonding network for automated assignment of histidine
#  protonation. 338 donors and 346 acceptors were found.
# There are 559 hydrogen bonds
# Will use HISE for residue 25
# Will use HISE for residue 77
# Will use HISE for residue 81
# Will use HISE for residue 139
# Will use HISE for residue 149
# Will use HISE for residue 170
# Will use HISE for residue 182
# Will use HISH for residue 200
# Will use HISD for residue 218
#
# Identified residue VAL1 as a starting terminus.
#
# Identified residue THR231 as a ending terminus.
# 9 out of 9 lines of specbond.dat converted successfully
# Special Atom Distance matrix:
#                    HIS25   CYS48   CYS70   HIS77   MET78   HIS81   MET88
#                   NE2184   SG355   SG502  NE2566   SD573  NE2602   SD659
#    CYS48   SG355   1.286
#    CYS70   SG502   3.154   2.374
#    HIS77  NE2566   4.574   4.053   2.058
#    MET78   SD573   4.156   3.658   1.687   0.446
#    HIS81  NE2602   4.434   4.001   1.870   0.856   0.713
#    MET88   SD659   3.399   2.645   0.543   2.302   1.951   1.945
#   HIS139 NE21077   0.839   1.023   2.901   4.187   3.802   4.198   3.254
#   HIS149 NE21163   3.464   3.100   2.159   1.651   1.465   2.108   2.647
#   MET154  SD1205   3.508   3.476   2.079   1.931   1.586   1.425   2.202
#   HIS170 NE21339   1.767   1.744   2.136   2.956   2.577   2.983   2.560
#   HIS182 NE21429   2.018   1.909   1.700   2.589   2.174   2.484   2.072
#   HIS200 NE21568   3.672   3.250   1.328   1.069   0.635   0.786   1.561
#   HIS218 NE21719   2.245   1.192   2.363   3.708   3.396   3.903   2.777
#   MET219  SD1726   1.951   1.187   1.792   3.041   2.685   3.158   2.250
#                   HIS139  HIS149  MET154  HIS170  HIS182  HIS200  HIS218
#                  NE21077 NE21163  SD1205 NE21339 NE21429 NE21568 NE21719
#   HIS149 NE21163   2.925
#   MET154  SD1205   3.445   2.071
#   HIS170 NE21339   1.351   1.709   2.225
#   HIS182 NE21429   1.780   1.667   1.693   0.614
#   HIS200 NE21568   3.412   1.564   1.106   2.209   1.713
#   HIS218 NE21719   1.559   2.648   3.699   1.883   2.156   3.181
#   MET219  SD1726   1.340   1.954   2.807   1.045   1.249   2.396   0.914
#
#
# Start terminus VAL-1: NH3+
# End terminus THR-231: COO-
# Opening force field file ./charmm36-jul2022.ff/aminoacids.arn
#
# Checking for duplicate atoms....
#
# Generating any missing hydrogen atoms and/or adding termini.
#
# Now there are 228 residues with 3583 atoms
#
# Making bonds...
#
# Long Bond (962-964 = 0.496946 nm)
#
# Long Bond (962-964 = 0.496946 nm)
#
# Number of bonds was 3626, now 3626
#
# Generating angles, dihedrals and pairs...
# Before cleaning: 9521 pairs
# Before cleaning: 9621 dihedrals
#
# Making cmap torsions...
#
# There are  226 cmap torsion pairs
#
# There are 9621 dihedrals,  641 impropers, 6554 angles
#           9449 pairs,     3626 bonds and     0 virtual sites
#
# Total mass 25684.155 a.m.u.
#
# Total charge -6.000 e
#
# Writing topology
#
# Writing coordinate file...
#
# 		--------- PLEASE NOTE ------------
#
# You have successfully generated a topology from: 3W1C_A.gro.
#
# The Charmm36-jul2022 force field and the tip3p water model are used.
#
# 		--------- ETON ESAELP ------------
#
# GROMACS reminds you: "There are three types of people: Those who see, those who see when they are shown, and those who do not see." (Leonardo da Vinci)

# %% [markdown]
# ## Running Energy Minimization
#
# Create a `.tpr` file which is a portable binary run input file that contains all the necessary information for performing an energy minimization on the protein structure in a vacuum.
# Ensure that the structure is stable and free from significant steric clashes or unrealistic geometries before proceeding to further simulations.

# %%
MIN_SD_MDP = Path(GROMACS_PATH) / "min_sd.mdp"
VACUUM_TPR = Path(f"{PROTEIN_PDB.stem}_vacuum.tpr")
# !cd {WD} && gmx grompp -v -f {MIN_SD_MDP} -c {PROTEIN_TOP_GRO} -p {PROTEIN_TOP} -o {VACUUM_TPR} -maxwarn 1
# Out:
#                       :-) GROMACS - gmx grompp, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx grompp -v -f /home/tz365/WS/ProtMatch/gromacs/min_sd.mdp -c 3W1C_A_top.gro -p 3W1C_A.top -o 3W1C_A_vacuum.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'ns_type'
# checking input for internal consistency...
#
# Setting the LD random seed to 1811725823
#
# processing topology...
#
# Generated 167799 of the 167910 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 117432 of the 167910 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# NOTE 1 [file 3W1C_A.top, line 34000]:
#   System has non-zero total charge: -6.000000
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file 3W1C_A.top, line 34000]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# processing coordinates...
#
# double-checking input for internal consistency...
# renumbering atomtypes...
#
# converting bonded parameters...
#
# initialising group options...
# processing index file...
# Analysing residue names:
# There are:   228    Protein residues
# Analysing Protein...
# Making dummy/rest group for T-Coupling containing 3583 elements
# Making dummy/rest group for Acc. not used containing 3583 elements
# Making dummy/rest group for Freeze containing 3583 elements
# Making dummy/rest group for Energy Mon. containing 3583 elements
# Making dummy/rest group for VCM containing 3583 elements
# Number of degrees of freedom in T-Coupling group rest is 10746.00
# Making dummy/rest group for User1 containing 3583 elements
# Making dummy/rest group for User2 containing 3583 elements
# Making dummy/rest group for Compressed X containing 3583 elements
# Making dummy/rest group for Or. Res. Fit containing 3583 elements
# Making dummy/rest group for QMMM containing 3583 elements
# T-Coupling       has 1 element(s): rest
# Energy Mon.      has 1 element(s): rest
# Acc. not used    has 1 element(s): rest
# Freeze           has 1 element(s): rest
# User1            has 1 element(s): rest
# User2            has 1 element(s): rest
# VCM              has 1 element(s): rest
# Compressed X     has 1 element(s): rest
# Or. Res. Fit     has 1 element(s): rest
# QMMM             has 1 element(s): rest
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# The largest distance between excluded atoms is 0.735 nm between atom 948 and 964
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 72x72x72, spacing 0.118 0.118 0.118
#
# Estimate for the relative computational load of the PME mesh part: 0.72
#
# NOTE 2 [file /home/tz365/WS/ProtMatch/gromacs/min_sd.mdp]:
#   The optimal PME mesh load for parallel simulations is below 0.5
#   and for highly parallel simulations between 0.25 and 0.33,
#   for higher performance, increase the cut-off and the PME grid spacing.
#
#
#
# This run will generate roughly 0 Mb of data
#
# writing run input file...
#
# There were 2 NOTEs
#
# There was 1 WARNING
#
# GROMACS reminds you: "Measuring programming progress by lines of code is like measuring aircraft building progress by weight." (Bill Gates)

# %% [markdown]
# Perform an energy minimization on the protein structure in a vacuum.
# This is to eliminate any steric clashes or inappropriate geometry in the molecular structure.
# It adjusts the positions of atoms to find a local minimum in the potential energy landscape, leading to a more stable conformation.

# %%
VACUUM_GRO = Path(f"{VACUUM_TPR.stem}.gro")
# !cd {WD} && gmx mdrun -v -deffnm {VACUUM_TPR.stem} -c {VACUUM_GRO} -gpu_id 0
# Out:
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx mdrun -v -deffnm 3W1C_A_vacuum -c 3W1C_A_vacuum.gro -gpu_id 0
#
# Reading file 3W1C_A_vacuum.tpr, VERSION 2024.2 (single precision)
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
# Using 24 OpenMP threads
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  2.00000e+00
#    Number of steps    =        30000
# Step=    0, Dmax= 1.0e-02 nm, Epot=  3.79570e+04 Fmax= 1.17204e+05, atom= 962
# Step=    1, Dmax= 1.0e-02 nm, Epot=  3.41192e+04 Fmax= 1.08272e+05, atom= 962
# Step=    2, Dmax= 1.2e-02 nm, Epot=  2.97959e+04 Fmax= 9.83176e+04, atom= 962
# Step=    3, Dmax= 1.4e-02 nm, Epot=  2.50232e+04 Fmax= 8.72874e+04, atom= 962
# Step=    4, Dmax= 1.7e-02 nm, Epot=  1.98972e+04 Fmax= 7.48948e+04, atom= 962
# Step=    5, Dmax= 2.1e-02 nm, Epot=  1.45814e+04 Fmax= 6.04798e+04, atom= 962
# Step=    6, Dmax= 2.5e-02 nm, Epot=  9.27545e+03 Fmax= 4.33243e+04, atom= 962
# Step=    7, Dmax= 3.0e-02 nm, Epot=  4.10547e+03 Fmax= 2.36856e+04, atom= 962
# Step=    8, Dmax= 3.6e-02 nm, Epot= -1.05421e+03 Fmax= 1.10849e+04, atom= 965
# Step=    9, Dmax= 4.3e-02 nm, Epot= -4.93442e+03 Fmax= 1.16160e+04, atom= 964
# Step=   11, Dmax= 2.6e-02 nm, Epot= -5.41793e+03 Fmax= 1.92231e+04, atom= 962
# Step=   12, Dmax= 3.1e-02 nm, Epot= -5.82296e+03 Fmax= 1.66646e+04, atom= 964
# Step=   14, Dmax= 1.9e-02 nm, Epot= -6.30341e+03 Fmax= 6.59572e+03, atom= 962
# Step=   15, Dmax= 2.2e-02 nm, Epot= -6.39135e+03 Fmax= 2.10333e+04, atom= 962
# Step=   16, Dmax= 2.7e-02 nm, Epot= -6.80572e+03 Fmax= 1.54918e+04, atom= 962
# Step=   18, Dmax= 1.6e-02 nm, Epot= -7.07607e+03 Fmax= 5.55821e+03, atom= 962
# Step=   20, Dmax= 9.6e-03 nm, Epot= -7.22568e+03 Fmax= 8.73842e+03, atom= 962
# Step=   21, Dmax= 1.2e-02 nm, Epot= -7.36417e+03 Fmax= 5.88915e+03, atom= 962
# Step=   22, Dmax= 1.4e-02 nm, Epot= -7.44458e+03 Fmax= 1.48389e+04, atom= 962
# Step=   23, Dmax= 1.7e-02 nm, Epot= -7.63323e+03 Fmax= 6.96890e+03, atom= 962
# Step=   25, Dmax= 1.0e-02 nm, Epot= -7.74356e+03 Fmax= 7.30813e+03, atom= 962
# Step=   26, Dmax= 1.2e-02 nm, Epot= -7.83829e+03 Fmax= 7.68933e+03, atom= 962
# Step=   27, Dmax= 1.4e-02 nm, Epot= -7.89432e+03 Fmax= 1.29351e+04, atom= 962
# Step=   28, Dmax= 1.7e-02 nm, Epot= -8.01157e+03 Fmax= 9.41545e+03, atom= 962
# Step=12121, Dmax= 3.2e-04 nm, Epot= -1.72182e+04 Fmax= 2.74419e+02, atom= 3089
# Step=12122, Dmax= 3.8e-04 nm, Epot= -1.72183e+04 Fmax= 2.62981e+02, atom= 3089
# Step=12124, Dmax= 2.3e-04 nm, Epot= -1.72185e+04 Fmax= 5.98343e+01, atom= 3089
# Step=12125, Dmax= 2.7e-04 nm, Epot= -1.72186e+04 Fmax= 3.27210e+02, atom= 3089
# Step=12126, Dmax= 3.3e-04 nm, Epot= -1.72187e+04 Fmax= 1.37100e+02, atom= 3089
# Step=12127, Dmax= 4.0e-04 nm, Epot= -1.72187e+04 Fmax= 4.20261e+02, atom= 3089
# Step=12128, Dmax= 4.8e-04 nm, Epot= -1.72189e+04 Fmax= 2.47963e+02, atom= 3089
# Step=12130, Dmax= 2.9e-04 nm, Epot= -1.72190e+04 Fmax= 1.53386e+02, atom= 3089
# Step=12139, Dmax= 1.3e-06 nm, Epot= -1.72190e+04 Fmax= 1.51461e+02, atom= 3089
# Energy minimization has stopped, but the forces have not converged to the
# requested precision Fmax < 2 (which may not be possible for your system). It
# stopped because the algorithm tried to make a new step whose size was too
# small, or there was no change in the energy since last step. Either way, we
# regard the minimization as converged to within the available machine
# precision, given your starting configuration and EM parameters.
#
# Double precision normally gives you higher accuracy, but this is often not
# needed for preparing to run molecular dynamics.
#
# writing lowest energy coordinates.
#
# Steepest Descents converged to machine precision in 12140 steps,
# but did not reach the requested Fmax < 2.
# Potential Energy  = -1.7219047e+04
# Maximum force     =  1.5338618e+02 on atom 3089
# Norm of force     =  6.0963004e+00
#
# GROMACS reminds you: "Since the mathematicians have invaded the theory of relativity I do not understand it myself any more." (Albert Einstein)

# %% [markdown]
# Analyse and visualize the energy minimization results.

# %%
VACUUM_EDR = Path(f"{VACUUM_GRO.stem}.edr")
VACUUM_XVG = Path(f"{VACUUM_GRO.stem}.xvg")
# !cd {WD} && echo "11" | gmx energy -f {VACUUM_EDR} -o {VACUUM_XVG} -xvg none

fig, ax = plt.subplots(figsize=(3, 3))
df = pd.read_csv(WD / VACUUM_XVG, sep='\s+', header=None, names=['step', 'energy'])
plt.plot(df["step"], df["energy"], color="black")
plt.xlabel("step")
plt.ylabel("energy (kJ/mol)")
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))
plt.grid(False)
plt.show()
# Out:
#                       :-) GROMACS - gmx energy, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx energy -f 3W1C_A_vacuum.edr -o 3W1C_A_vacuum.xvg -xvg none
#
# Opened 3W1C_A_vacuum.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Pressure
#  13  Vir-XX          14  Vir-XY          15  Vir-XZ          16  Vir-YX
#  17  Vir-YY          18  Vir-YZ          19  Vir-ZX          20  Vir-ZY
#  21  Vir-ZZ          22  Pres-XX         23  Pres-XY         24  Pres-XZ
#  25  Pres-YX         26  Pres-YY         27  Pres-YZ         28  Pres-ZX
#  29  Pres-ZY         30  Pres-ZZ         31  #Surf*SurfTen   32  T-rest
#
# Last energy frame read 9600 time 12130.000
#
# Statistics over 12131 steps [ 0.0000 through 12130.0000 ps ], 1 data sets
# All statistics are over 9601 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Potential                  -15730.1        650    1807.98   -4511.31  (kJ/mol)
#
# GROMACS reminds you: "Since the mathematicians have invaded the theory of relativity I do not understand it myself any more." (Albert Einstein)

# %% [markdown]
# ## Solvating the System
#
# Surrounding the protein with water molecules to create a realistic biological environment for molecular dynamics simulations.

# %%
WATER_GRO = Path(f"{PROTEIN_PDB.stem}_water.gro")
# !cd {WD} && gmx solvate -cp {VACUUM_GRO} -cs spc216.gro -p {PROTEIN_TOP} -o {WATER_GRO}
# Out:
#                      :-) GROMACS - gmx solvate, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx solvate -cp 3W1C_A_vacuum.gro -cs spc216.gro -p 3W1C_A.top -o 3W1C_A_water.gro
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Generating solvent configuration
# Will generate new solvent configuration of 5x5x4 boxes
# Solvent box contains 52554 atoms in 17518 residues
# Removed 6612 solvent atoms due to solvent-solvent overlap
# Removed 3315 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#     SOL (   3 atoms): 14209 residues
# Generated solvent containing 42627 atoms in 14209 residues
# Writing generated configuration to 3W1C_A_water.gro
#
# Output configuration contains 46210 atoms in 14437 residues
# Volume                 :     467.795 (nm^3)
# Density                :     1006.04 (g/l)
# Number of solvent molecules:  14209
#
# Processing topology
# Adding line for 14209 solvent molecules with resname (SOL) to topology file (3W1C_A.top)
#
# Back Off! I just backed up 3W1C_A.top to ./#3W1C_A.top.1#
#
# GROMACS reminds you: "Raw data is like raw sewage, it requires some processing before it can be spread around. The opposite is true of theories." (Jim Carr)

# %% [markdown]
# Remove any water molecules that may have inadvertently entered the core of the protein (within 3 Ångströms of the protein) during the solvation process.
# Internal water molecules within the protein core can interfere with the protein's structure and function.

# %%
WATER_RM_GRO = Path(f"{PROTEIN_PDB.stem}_waterRM.gro")
DEL_H2O_TCL = Path(GROMACS_PATH) / "del_wat_inside.tcl"
# !cd {WD} && vmd -dispdev text -eofexit -args < {DEL_H2O_TCL} {WATER_GRO} {PROTEIN_TOP} {WATER_RM_GRO}
# Out:
# Info) VMD for LINUXAMD64, version 1.9.4a57 (April 27, 2022)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 24 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info)   Detected VM or hypervisor execution environment
# Info) Free system memory: 30GB (95%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Unable to load NVML library, GPU-CPU affinity unavailable.
# Info) Detected 1 available CUDA accelerator::
# Info) [0] NVIDIA GeForce RTX 4090 128 SM_8.9 2.6 GHz, 24GB RAM SP64 KT AE1 ZC
# OptiXRenderer) ERROR: Failed to load OptiX shared library.
# OptiXRenderer)        NVIDIA driver may be too old.
# OptiXRenderer)        Check/update NVIDIA driver
# Info) Dynamically loaded 3 plugins in directory:
# Info) /usr/local/lib/vmd/plugins/LINUXAMD64/molfile
# 3W1C_A_water.gro
# 3W1C_A.top
# 3W1C_A_waterRM.gro
# Info) Using plugin gro for structure file 3W1C_A_water.gro
# Info) Using plugin gro for coordinates from file 3W1C_A_water.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file 3W1C_A_water.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 46210
# Info)    Bonds: 32018
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 14460
# Info)    Waters: 14209
# Warning) Unusual bond between residues:  102 (protein) and 103 (none)
# Warning) Unusual bond between residues:  103 (none) and 104 (protein)
# Warning) Unusual bond between residues:  128 (protein) and 129 (none)
# Warning) Unusual bond between residues:  130 (none) and 131 (protein)
# Warning) Unusual bond between residues:  133 (protein) and 134 (none)
# Warning) Unusual bond between residues:  173 (protein) and 174 (none)
# Warning) Unusual bond between residues:  174 (none) and 175 (protein)
# Info)    Segments: 1
# Info)    Fragments: 14236   Protein: 6   Nucleic: 0
# 0
# atomselect0
# atomselect1
# file15
# Info) Opened coordinate file 3W1C_A_waterRM.gro for writing.
# Info) Finished with coordinate file 3W1C_A_waterRM.gro.
# 527
# file15
# 13682
# Info) VMD for LINUXAMD64, version 1.9.4a57 (April 27, 2022)
# Info) Exiting normally.

# %% [markdown]
# You may need to correct formatting issues in the GRO file generated during the molecular dynamics simulation setup process.
# See https://github.com/allison-group/structural-phylogenetics-bootstrap/blob/master/MD/GMX/fix_gro.py

# %% [markdown]
# ## Energy Minimization After Adding Waters

# %%
WATER_RM_TPR = Path(f"{WATER_RM_GRO.stem}.tpr")
# !cd {WD} && gmx grompp -v -f {MIN_SD_MDP} -c {WATER_RM_GRO} -p {PROTEIN_TOP} -o {WATER_RM_TPR} -maxwarn 1
# Out:
#                       :-) GROMACS - gmx grompp, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx grompp -v -f /home/tz365/WS/ProtMatch/gromacs/min_sd.mdp -c 3W1C_A_waterRM.gro -p 3W1C_A.top -o 3W1C_A_waterRM.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'ns_type'
# checking input for internal consistency...
#
# Setting the LD random seed to -545341713
#
# processing topology...
#
# Generated 167799 of the 167910 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 117432 of the 167910 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# NOTE 1 [file 3W1C_A.top, line 34001]:
#   System has non-zero total charge: -6.000000
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file 3W1C_A.top, line 34001]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# processing coordinates...
#
# double-checking input for internal consistency...
# renumbering atomtypes...
#
# converting bonded parameters...
#
# initialising group options...
# processing index file...
# Analysing residue names:
# There are:   228    Protein residues
# There are: 13682      Water residues
# Analysing Protein...
# Making dummy/rest group for T-Coupling containing 44629 elements
# Making dummy/rest group for Acc. not used containing 44629 elements
# Making dummy/rest group for Freeze containing 44629 elements
# Making dummy/rest group for Energy Mon. containing 44629 elements
# Making dummy/rest group for VCM containing 44629 elements
# Number of degrees of freedom in T-Coupling group rest is 92838.00
# Making dummy/rest group for User1 containing 44629 elements
# Making dummy/rest group for User2 containing 44629 elements
# Making dummy/rest group for Compressed X containing 44629 elements
# Making dummy/rest group for Or. Res. Fit containing 44629 elements
# Making dummy/rest group for QMMM containing 44629 elements
# T-Coupling       has 1 element(s): rest
# Energy Mon.      has 1 element(s): rest
# Acc. not used    has 1 element(s): rest
# Freeze           has 1 element(s): rest
# User1            has 1 element(s): rest
# User2            has 1 element(s): rest
# VCM              has 1 element(s): rest
# Compressed X     has 1 element(s): rest
# Or. Res. Fit     has 1 element(s): rest
# QMMM             has 1 element(s): rest
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# The largest distance between excluded atoms is 0.427 nm between atom 2366 and 2374
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 72x72x72, spacing 0.118 0.118 0.118
#
# Estimate for the relative computational load of the PME mesh part: 0.18
#
# This run will generate roughly 4 Mb of data
#
# writing run input file...
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "Is This the Right Room for an Argument ?" (Monty Python)

# %% [markdown]
# Adding ions to neutralize the system:
#
# Add the appropriate number of positive (Na+) and negative (Cl-) ions to the solvated protein system. We aim to approximate physiological conditions and use therefore a NaCl concentration of 0.15 M.

# %%
SOLVATED_GRO = Path(f"{WATER_RM_TPR.stem}_solvated.gro")
# !cd {WD} && echo SOL | gmx genion -s {WATER_RM_TPR} -o {SOLVATED_GRO} -conc 0.15 -pname NA -nname CL -neutral -p {PROTEIN_TOP}
# Out:
#                       :-) GROMACS - gmx genion, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx genion -s 3W1C_A_waterRM.tpr -o 3W1C_A_waterRM_solvated.gro -conc 0.15 -pname NA -nname CL -neutral -p 3W1C_A.top
#
# Reading file 3W1C_A_waterRM.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_waterRM.tpr, VERSION 2024.2 (single precision)
# Will try to add 48 NA ions and 42 CL ions.
# Select a continuous group of solvent molecules
# Group     0 (         System) has 44629 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 41046 elements
# Group    12 (          Water) has 41046 elements
# Group    13 (            SOL) has 41046 elements
# Group    14 (      non-Water) has  3583 elements
# Select a group: Selected 13: 'SOL'
# Number of (3-atomic) solvent molecules: 13682
#
# Processing topology
# Replacing 90 solute molecules in topology file (3W1C_A.top)  by 48 NA and 42 CL ions.
#
# Back Off! I just backed up 3W1C_A.top to ./#3W1C_A.top.2#
# Using random seed -268454431.
# Replacing solvent molecule 10234 (atom 34285) with NA
# Replacing solvent molecule 5364 (atom 19675) with NA
# Replacing solvent molecule 1291 (atom 7456) with NA
# Replacing solvent molecule 5838 (atom 21097) with NA
# Replacing solvent molecule 9655 (atom 32548) with NA
# Replacing solvent molecule 7569 (atom 26290) with NA
# Replacing solvent molecule 11668 (atom 38587) with NA
# Replacing solvent molecule 2797 (atom 11974) with NA
# Replacing solvent molecule 1670 (atom 8593) with NA
# Replacing solvent molecule 12029 (atom 39670) with NA
# Replacing solvent molecule 1706 (atom 8701) with NA
# Replacing solvent molecule 8015 (atom 27628) with NA
# Replacing solvent molecule 9879 (atom 33220) with NA
# Replacing solvent molecule 10610 (atom 35413) with NA
# Replacing solvent molecule 11346 (atom 37621) with NA
# Replacing solvent molecule 13412 (atom 43819) with NA
# Replacing solvent molecule 8558 (atom 29257) with NA
# Replacing solvent molecule 9603 (atom 32392) with NA
# Replacing solvent molecule 6234 (atom 22285) with NA
# Replacing solvent molecule 7131 (atom 24976) with NA
# Replacing solvent molecule 11064 (atom 36775) with NA
# Replacing solvent molecule 6828 (atom 24067) with NA
# Replacing solvent molecule 13355 (atom 43648) with NA
# Replacing solvent molecule 1868 (atom 9187) with NA
# Replacing solvent molecule 9808 (atom 33007) with NA
# Replacing solvent molecule 4736 (atom 17791) with NA
# Replacing solvent molecule 5277 (atom 19414) with NA
# Replacing solvent molecule 12148 (atom 40027) with NA
# Replacing solvent molecule 11755 (atom 38848) with NA
# Replacing solvent molecule 609 (atom 5410) with NA
# Replacing solvent molecule 11025 (atom 36658) with NA
# Replacing solvent molecule 6976 (atom 24511) with NA
# Replacing solvent molecule 657 (atom 5554) with NA
# Replacing solvent molecule 6701 (atom 23686) with NA
# Replacing solvent molecule 6682 (atom 23629) with NA
# Replacing solvent molecule 4044 (atom 15715) with NA
# Replacing solvent molecule 12356 (atom 40651) with NA
# Replacing solvent molecule 12815 (atom 42028) with NA
# Replacing solvent molecule 2639 (atom 11500) with NA
# Replacing solvent molecule 531 (atom 5176) with NA
# Replacing solvent molecule 2885 (atom 12238) with NA
# Replacing solvent molecule 9074 (atom 30805) with NA
# Replacing solvent molecule 5056 (atom 18751) with NA
# Replacing solvent molecule 13170 (atom 43093) with NA
# Replacing solvent molecule 877 (atom 6214) with NA
# Replacing solvent molecule 9895 (atom 33268) with NA
# Replacing solvent molecule 7654 (atom 26545) with NA
# Replacing solvent molecule 3072 (atom 12799) with NA
# Replacing solvent molecule 3619 (atom 14440) with CL
# Replacing solvent molecule 6995 (atom 24568) with CL
# Replacing solvent molecule 4812 (atom 18019) with CL
# Replacing solvent molecule 3466 (atom 13981) with CL
# Replacing solvent molecule 2986 (atom 12541) with CL
# Replacing solvent molecule 3126 (atom 12961) with CL
# Replacing solvent molecule 8987 (atom 30544) with CL
# Replacing solvent molecule 1822 (atom 9049) with CL
# Replacing solvent molecule 1675 (atom 8608) with CL
# Replacing solvent molecule 11068 (atom 36787) with CL
# Replacing solvent molecule 12492 (atom 41059) with CL
# Replacing solvent molecule 6607 (atom 23404) with CL
# Replacing solvent molecule 725 (atom 5758) with CL
# Replacing solvent molecule 4610 (atom 17413) with CL
# Replacing solvent molecule 7370 (atom 25693) with CL
# Replacing solvent molecule 3317 (atom 13534) with CL
# Replacing solvent molecule 8621 (atom 29446) with CL
# Replacing solvent molecule 5533 (atom 20182) with CL
# Replacing solvent molecule 2771 (atom 11896) with CL
# Replacing solvent molecule 4405 (atom 16798) with CL
# Replacing solvent molecule 12379 (atom 40720) with CL
# Replacing solvent molecule 2436 (atom 10891) with CL
# Replacing solvent molecule 4300 (atom 16483) with CL
# Replacing solvent molecule 5269 (atom 19390) with CL
# Replacing solvent molecule 741 (atom 5806) with CL
# Replacing solvent molecule 7936 (atom 27391) with CL
# Replacing solvent molecule 7189 (atom 25150) with CL
# Replacing solvent molecule 4849 (atom 18130) with CL
# Replacing solvent molecule 858 (atom 6157) with CL
# Replacing solvent molecule 8718 (atom 29737) with CL
# Replacing solvent molecule 4506 (atom 17101) with CL
# Replacing solvent molecule 7915 (atom 27328) with CL
# Replacing solvent molecule 3355 (atom 13648) with CL
# Replacing solvent molecule 13323 (atom 43552) with CL
# Replacing solvent molecule 7563 (atom 26272) with CL
# Replacing solvent molecule 12958 (atom 42457) with CL
# Replacing solvent molecule 3737 (atom 14794) with CL
# Replacing solvent molecule 10411 (atom 34816) with CL
# Replacing solvent molecule 2386 (atom 10741) with CL
# Replacing solvent molecule 876 (atom 6211) with CL
# Replacing solvent molecule 9512 (atom 32119) with CL
# Replacing solvent molecule 7769 (atom 26890) with CL
#
#
# GROMACS reminds you: "Is This the Right Room for an Argument ?" (Monty Python)

# %% [markdown]
# Minimize energy again.

# %%
SOLVATED_TPR = Path(f"{SOLVATED_GRO.stem}.tpr")
# !cd {WD} && gmx grompp -v -f {MIN_SD_MDP} -c {SOLVATED_GRO} -p {PROTEIN_TOP} -o {SOLVATED_TPR}
# Out:
#                       :-) GROMACS - gmx grompp, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx grompp -v -f /home/tz365/WS/ProtMatch/gromacs/min_sd.mdp -c 3W1C_A_waterRM_solvated.gro -p 3W1C_A.top -o 3W1C_A_waterRM_solvated.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
# checking input for internal consistency...
#
# Setting the LD random seed to -100731913
#
# processing topology...
#
# Generated 167799 of the 167910 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 117432 of the 167910 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# Excluding 3 bonded neighbours molecule type 'NA'
#
# Excluding 3 bonded neighbours molecule type 'CL'
#
# processing coordinates...
#
# double-checking input for internal consistency...
# renumbering atomtypes...
#
# converting bonded parameters...
#
# initialising group options...
# processing index file...
# Analysing residue names:
# There are:   228    Protein residues
# There are: 13592      Water residues
# There are:    90        Ion residues
# Analysing Protein...
# Making dummy/rest group for T-Coupling containing 44449 elements
# Making dummy/rest group for Acc. not used containing 44449 elements
# Making dummy/rest group for Freeze containing 44449 elements
# Making dummy/rest group for Energy Mon. containing 44449 elements
# Making dummy/rest group for VCM containing 44449 elements
# Number of degrees of freedom in T-Coupling group rest is 92568.00
# Making dummy/rest group for User1 containing 44449 elements
# Making dummy/rest group for User2 containing 44449 elements
# Making dummy/rest group for Compressed X containing 44449 elements
# Making dummy/rest group for Or. Res. Fit containing 44449 elements
# Making dummy/rest group for QMMM containing 44449 elements
# T-Coupling       has 1 element(s): rest
# Energy Mon.      has 1 element(s): rest
# Acc. not used    has 1 element(s): rest
# Freeze           has 1 element(s): rest
# User1            has 1 element(s): rest
# User2            has 1 element(s): rest
# VCM              has 1 element(s): rest
# Compressed X     has 1 element(s): rest
# Or. Res. Fit     has 1 element(s): rest
# QMMM             has 1 element(s): rest
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# The largest distance between excluded atoms is 0.427 nm between atom 2366 and 2374
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 72x72x72, spacing 0.118 0.118 0.118
#
# Estimate for the relative computational load of the PME mesh part: 0.18
#
# This run will generate roughly 4 Mb of data
#
# writing run input file...
#
# GROMACS reminds you: "Prior to 1965 there were none, and after 1965 there was a nun." (Sister Mary Kenneth Keller regarding women with PhDs in computer science)

# %%
# !cd {WD} && gmx mdrun -v -deffnm {SOLVATED_TPR.stem} -c {SOLVATED_GRO} -gpu_id 0
# Out:
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx mdrun -v -deffnm 3W1C_A_waterRM_solvated -c 3W1C_A_waterRM_solvated.gro -gpu_id 0
#
# Reading file 3W1C_A_waterRM_solvated.tpr, VERSION 2024.2 (single precision)
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
# Using 24 OpenMP threads
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  2.00000e+00
#    Number of steps    =        30000
# Step=    0, Dmax= 1.0e-02 nm, Epot= -3.88600e+05 Fmax= 2.50817e+05, atom= 44425
# Step=    1, Dmax= 1.0e-02 nm, Epot= -4.17094e+05 Fmax= 1.02247e+05, atom= 44425
# Step=    2, Dmax= 1.2e-02 nm, Epot= -4.49352e+05 Fmax= 3.52696e+04, atom= 44425
# Step=    3, Dmax= 1.4e-02 nm, Epot= -4.84223e+05 Fmax= 1.22267e+04, atom= 41519
# Step=    4, Dmax= 1.7e-02 nm, Epot= -5.14369e+05 Fmax= 6.17640e+03, atom= 13112
# Step=    5, Dmax= 2.1e-02 nm, Epot= -5.39489e+05 Fmax= 4.20193e+03, atom= 13112
# Step=    6, Dmax= 2.5e-02 nm, Epot= -5.61092e+05 Fmax= 1.16295e+04, atom= 2704
# Step=    7, Dmax= 3.0e-02 nm, Epot= -5.61577e+05 Fmax= 2.79809e+04, atom= 2704
# Step=    8, Dmax= 3.6e-02 nm, Epot= -5.68508e+05 Fmax= 1.96619e+04, atom= 2704
# Step=   10, Dmax= 2.1e-02 nm, Epot= -5.73497e+05 Fmax= 9.33533e+03, atom= 2704
# Step=   11, Dmax= 2.6e-02 nm, Epot= -5.74236e+05 Fmax= 2.52343e+04, atom= 2704
# Step=   12, Dmax= 3.1e-02 nm, Epot= -5.79470e+05 Fmax= 1.66804e+04, atom= 2704
# Step=   14, Dmax= 1.9e-02 nm, Epot= -5.83014e+05 Fmax= 8.35309e+03, atom= 2704
# Step=   15, Dmax= 2.2e-02 nm, Epot= -5.83980e+05 Fmax= 2.20102e+04, atom= 2704
# Step=   16, Dmax= 2.7e-02 nm, Epot= -5.87953e+05 Fmax= 1.40377e+04, atom= 2704
# Step=   18, Dmax= 1.6e-02 nm, Epot= -5.90604e+05 Fmax= 7.66492e+03, atom= 2704
# Step=   19, Dmax= 1.9e-02 nm, Epot= -5.91772e+05 Fmax= 1.83794e+04, atom= 2064
# Step=   20, Dmax= 2.3e-02 nm, Epot= -5.94610e+05 Fmax= 1.32309e+04, atom= 2064
# Step=   22, Dmax= 1.4e-02 nm, Epot= -5.96881e+05 Fmax= 5.63888e+03, atom= 2064
# Step=   23, Dmax= 1.7e-02 nm, Epot= -5.98466e+05 Fmax= 1.70088e+04, atom= 2064
# Step=   24, Dmax= 2.0e-02 nm, Epot= -6.00954e+05 Fmax= 1.02095e+04, atom= 2064
# Step=   26, Dmax= 1.2e-02 nm, Epot= -6.02577e+05 Fmax= 6.18955e+03, atom= 2064
# Step=   27, Dmax= 1.4e-02 nm, Epot= -6.03992e+05 Fmax= 1.35120e+04, atom= 2064
# Step=   28, Dmax= 1.7e-02 nm, Epot= -6.05667e+05 Fmax= 1.00816e+04, atom= 2064
# Step=   29, Dmax= 2.1e-02 nm, Epot= -6.06231e+05 Fmax= 1.83678e+04, atom= 2064
# Step= 5404, Dmax= 2.1e-03 nm, Epot= -7.33447e+05 Fmax= 1.30565e+03, atom= 3089
# Step= 5406, Dmax= 1.2e-03 nm, Epot= -7.33450e+05 Fmax= 4.48486e+02, atom= 3089
# Step= 5407, Dmax= 1.5e-03 nm, Epot= -7.33452e+05 Fmax= 1.65994e+03, atom= 3089
# Step= 5408, Dmax= 1.8e-03 nm, Epot= -7.33455e+05 Fmax= 8.68146e+02, atom= 3089
# Step= 5410, Dmax= 1.1e-03 nm, Epot= -7.33458e+05 Fmax= 6.50878e+02, atom= 3089
# Step= 5419, Dmax= 5.1e-06 nm, Epot= -7.33458e+05 Fmax= 6.43465e+02, atom= 3089
# Step= 5422, Dmax= 1.5e-06 nm, Epot= -7.33457e+05 Fmax= 6.41517e+02, atom= 3089
# Energy minimization has stopped, but the forces have not converged to the
# requested precision Fmax < 2 (which may not be possible for your system). It
# stopped because the algorithm tried to make a new step whose size was too
# small, or there was no change in the energy since last step. Either way, we
# regard the minimization as converged to within the available machine
# precision, given your starting configuration and EM parameters.
#
# Double precision normally gives you higher accuracy, but this is often not
# needed for preparing to run molecular dynamics.
# You might need to increase your constraint accuracy, or turn
# off constraints altogether (set constraints = none in mdp file)
#
# writing lowest energy coordinates.
#
# Back Off! I just backed up 3W1C_A_waterRM_solvated.gro to ./#3W1C_A_waterRM_solvated.gro.1#
#
# Steepest Descents converged to machine precision in 5423 steps,
# but did not reach the requested Fmax < 2.
# Potential Energy  = -7.3345825e+05
# Maximum force     =  6.4346454e+02 on atom 3089
# Norm of force     =  7.8894954e+00
#
# GROMACS reminds you: "Money won't buy happiness, but it will pay the salaries of a large research staff to study the problem." (Bill Vaughan)

# %%
VACUUM_EDR = Path(f"{SOLVATED_GRO.stem}.edr")
VACUUM_XVG = Path(f"{SOLVATED_GRO.stem}.xvg")
# !cd {WD} && echo "11" | gmx energy -f {VACUUM_EDR} -o {VACUUM_XVG} -xvg none

fig, ax = plt.subplots(figsize=(3, 3))
df = pd.read_csv(WD / VACUUM_XVG, sep='\s+', header=None, names=['step', 'energy'])
plt.plot(df["step"], df["energy"], color="black")
plt.xlabel("step")
plt.ylabel("energy (kJ/mol)")
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))
plt.grid(False)
plt.show()
# Out:
#                       :-) GROMACS - gmx energy, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx energy -f 3W1C_A_waterRM_solvated.edr -o 3W1C_A_waterRM_solvated.xvg -xvg none
#
# Opened 3W1C_A_waterRM_solvated.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Pressure
#  13  Vir-XX          14  Vir-XY          15  Vir-XZ          16  Vir-YX
#  17  Vir-YY          18  Vir-YZ          19  Vir-ZX          20  Vir-ZY
#  21  Vir-ZZ          22  Pres-XX         23  Pres-XY         24  Pres-XZ
#  25  Pres-YX         26  Pres-YY         27  Pres-YZ         28  Pres-ZX
#  29  Pres-ZY         30  Pres-ZZ         31  #Surf*SurfTen   32  T-rest
#
# Last energy frame read 4282 time 5419.000
#
# Statistics over 5420 steps [ 0.0000 through 5419.0000 ps ], 1 data sets
# All statistics are over 4283 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Potential                   -717691       8600      22301   -55692.5  (kJ/mol)
#
# GROMACS reminds you: "Money won't buy happiness, but it will pay the salaries of a large research staff to study the problem." (Bill Vaughan)

# %% [markdown]
# ## Equilibration - Temperature
#
# Perform NVT (constant Number of particles, Volume, and Temperature) heating on the solvated protein system,
# where the system is gradually heated to the target temperature under constant volume conditions.
#
# The main goals are:
# - to slowly increase the temperature of the system, allowing it to adapt without causing structural distortions or instabilities.
# - to equilibrate the kinetic energy distribution among the particles, ensuring a stable temperature before proceeding to subsequent simulation steps.

# %%
NVT_MDP = Path(GROMACS_PATH) / "nvt.mdp"
NVT_NN = f"{PROTEIN_PDB.stem}_NVT"
NVT_TPR = Path(f"{NVT_NN}.tpr")
# !cd {WD} && gmx grompp -v -f {NVT_MDP} -c {SOLVATED_GRO} -p {PROTEIN_TOP} -r {SOLVATED_GRO} -o {NVT_TPR}
# !cd {WD} && gmx mdrun -v -deffnm {NVT_NN} -s {NVT_TPR} -gpu_id 0
# Out:
#                       :-) GROMACS - gmx grompp, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx grompp -v -f /home/tz365/WS/ProtMatch/gromacs/nvt.mdp -c 3W1C_A_waterRM_solvated.gro -p 3W1C_A.top -r 3W1C_A_waterRM_solvated.gro -o 3W1C_A_NVT.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
# checking input for internal consistency...
#
# Setting the LD random seed to -1411915801
#
# processing topology...
#
# Generated 167799 of the 167910 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 117432 of the 167910 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'NA'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'CL'
#
# turning H bonds into constraints...
#
# processing coordinates...
#
# double-checking input for internal consistency...
#
# Setting gen_seed to 1600581369
#
# Velocities were taken from a Maxwell distribution at 50 K
#
# Reading position restraint coords from 3W1C_A_waterRM_solvated.gro
# renumbering atomtypes...
#
# converting bonded parameters...
#
# initialising group options...
# processing index file...
# Analysing residue names:
# There are:   228    Protein residues
# There are: 13592      Water residues
# There are:    90        Ion residues
# Analysing Protein...
# Simulated annealing for group Protein: Single, 3 timepoints
# Time (ps)   Temperature (K)
#       0.0       50.0
#      10.0       50.0
#     210.0-     310.0
# Simulated annealing for group Water_and_ions: Single, 3 timepoints
# Time (ps)   Temperature (K)
#       0.0       50.0
#      10.0       50.0
#     210.0-     310.0
# Making dummy/rest group for Acc. not used containing 44449 elements
# Making dummy/rest group for Freeze containing 44449 elements
# Making dummy/rest group for Energy Mon. containing 44449 elements
# Making dummy/rest group for VCM containing 44449 elements
# Number of degrees of freedom in T-Coupling group Protein is 8979.70
# Number of degrees of freedom in T-Coupling group Water_and_ions is 81819.30
# Making dummy/rest group for User1 containing 44449 elements
# Making dummy/rest group for User2 containing 44449 elements
# Making dummy/rest group for Compressed X containing 44449 elements
# Making dummy/rest group for Or. Res. Fit containing 44449 elements
# Making dummy/rest group for QMMM containing 44449 elements
# T-Coupling       has 2 element(s): Protein Water_and_ions
# Energy Mon.      has 1 element(s): rest
# Acc. not used    has 1 element(s): rest
# Freeze           has 1 element(s): rest
# User1            has 1 element(s): rest
# User2            has 1 element(s): rest
# VCM              has 1 element(s): rest
# Compressed X     has 1 element(s): rest
# Or. Res. Fit     has 1 element(s): rest
# QMMM             has 1 element(s): rest
# Simulated tempering is used with multiple T-coupling groups: setting the ensemble temperature to not available
#
# The largest distance between excluded atoms is 0.426 nm between atom 2366 and 2374
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 310 K
#
# Calculated rlist for 1x1 atom pair-list as 1.234 nm, buffer size 0.034 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# NOTE 1 [file /home/tz365/WS/ProtMatch/gromacs/nvt.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 72x72x72, spacing 0.118 0.118 0.118
#
# Estimate for the relative computational load of the PME mesh part: 0.19
#
# This run will generate roughly 14 Mb of data
#
# writing run input file...
#
# There was 1 NOTE
#
# GROMACS reminds you: "Throughout my academic career, I'd given some pretty good talks. But being considered the best speaker in the computer science department is like being known as the tallest of the Seven Dwarfs." (Randy Pausch)
#
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx mdrun -v -deffnm 3W1C_A_NVT -s 3W1C_A_NVT.tpr -gpu_id 0
#
# Reading file 3W1C_A_NVT.tpr, VERSION 2024.2 (single precision)
# Changing nstlist from 10 to 100, rlist from 1.2 to 1.358
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 2 GPU tasks in the 1 rank on this node:
#   PP:0,PME:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the GPU
# PME tasks will do all aspects on the GPU
# Using 1 MPI thread
# Using 12 OpenMP threads
#
# starting mdrun 'Guyana Rwanda Oman Macau Angola Cameroon Senegal in water'
# 250000 steps,    500.0 ps.
# step 13100: timed with pme grid 72 72 72, coulomb cutoff 1.200: 123.5 M-cycles
# step 13300: timed with pme grid 60 60 60, coulomb cutoff 1.412: 141.9 M-cycles
# step 13500: timed with pme grid 64 64 64, coulomb cutoff 1.323: 135.0 M-cycles
# step 13700: timed with pme grid 72 72 72, coulomb cutoff 1.200: 127.9 M-cycles
#               optimal pme grid 72 72 72, coulomb cutoff 1.200
# step 249900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 250000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     1159.710       96.644     1200.0
#                  (ns/day)    (hour/ns)
# Performance:      447.005        0.054
#
# GROMACS reminds you: "A weed scientist goes into a shop. He asks: 'Hey, you got any of that inhibitor of 3-phosphoshikimate-carboxyvinyl transferase?' Shopkeeper: 'You mean Roundup?' Scientist: 'Yeah, that's it. I can never remember that dang name!'" (John Pickett)

# %%
NVT_EDR = Path(f"{NVT_NN}.edr")
NVT_XVG = Path(f"{NVT_NN}.xvg")
# !cd {WD} && echo "Temperature" | gmx energy -f {NVT_EDR} -o {NVT_XVG} -xvg none -b 20

fig, ax = plt.subplots(figsize=(3, 3))
df = pd.read_csv(WD / NVT_XVG, sep='\s+', header=None, names=['time', 'temperature'])
plt.plot(df["time"], df["temperature"], color="black")
plt.axhline(y=300, color='black', linestyle='--', linewidth=0.8)
plt.xlabel("time (ps)")
plt.ylabel("temperature (K)")
plt.grid(False)
plt.show()
# Out:
#                       :-) GROMACS - gmx energy, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx energy -f 3W1C_A_NVT.edr -o 3W1C_A_NVT.xvg -xvg none -b 20
#
# Opened 3W1C_A_NVT.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Position-Rest.  12  Potential
#  13  Kinetic-En.     14  Total-Energy    15  Conserved-En.   16  Temperature
#  17  Pressure        18  Constr.-rmsd    19  Vir-XX          20  Vir-XY
#  21  Vir-XZ          22  Vir-YX          23  Vir-YY          24  Vir-YZ
#  25  Vir-ZX          26  Vir-ZY          27  Vir-ZZ          28  Pres-XX
#  29  Pres-XY         30  Pres-XZ         31  Pres-YX         32  Pres-YY
#  33  Pres-YZ         34  Pres-ZX         35  Pres-ZY         36  Pres-ZZ
#  37  #Surf*SurfTen                       38  T-Protein
#  39  T-Water_and_ions                    40  Lamb-Protein
#  41  Lamb-Water_and_ions
#
# Last energy frame read 50 time  500.000
#
# Statistics over 240001 steps [ 20.0000 through 500.0000 ps ], 1 data sets
# All statistics are over 2401 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                  260.91         35    75.3984    216.313  (K)
#
# GROMACS reminds you: "A weed scientist goes into a shop. He asks: 'Hey, you got any of that inhibitor of 3-phosphoshikimate-carboxyvinyl transferase?' Shopkeeper: 'You mean Roundup?' Scientist: 'Yeah, that's it. I can never remember that dang name!'" (John Pickett)

# %% [markdown]
# ## Equilibration - Pressure
#
# NPT (constant Number of particles, Pressure, and Temperature) equilibration allows the system to adjust its volume to achieve the target temperature and pressure.

# %%
NPT_MDP = Path(GROMACS_PATH) / "npt.mdp"
NVT_GRO = Path(f"{NVT_NN}.gro")
NVT_CPT = Path(f"{NVT_NN}.cpt")
NPT_NN = f"{PROTEIN_PDB.stem}_NPT"
NPT_TPR = Path(f"{NPT_NN}.tpr")
# !cd {WD} && gmx grompp -v -f {NPT_MDP} -c {NVT_GRO} -t {NVT_CPT} -p {PROTEIN_TOP} -o {NPT_TPR}
# !cd {WD} && gmx mdrun -v -deffnm {NPT_NN} -s {NPT_TPR} -gpu_id 0
# Out:
#                       :-) GROMACS - gmx grompp, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx grompp -v -f /home/tz365/WS/ProtMatch/gromacs/npt.mdp -c 3W1C_A_NVT.gro -t 3W1C_A_NVT.cpt -p 3W1C_A.top -o 3W1C_A_NPT.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
# checking input for internal consistency...
#
# Setting the LD random seed to -1275072551
#
# processing topology...
#
# Generated 167799 of the 167910 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 117432 of the 167910 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'NA'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'CL'
#
# turning H bonds into constraints...
#
# processing coordinates...
#
# double-checking input for internal consistency...
# renumbering atomtypes...
#
# converting bonded parameters...
#
# initialising group options...
# processing index file...
# Analysing residue names:
# There are:   228    Protein residues
# There are: 13592      Water residues
# There are:    90        Ion residues
# Analysing Protein...
# Making dummy/rest group for Acc. not used containing 44449 elements
# Making dummy/rest group for Freeze containing 44449 elements
# Making dummy/rest group for Energy Mon. containing 44449 elements
# Making dummy/rest group for VCM containing 44449 elements
# Number of degrees of freedom in T-Coupling group Protein is 8979.70
# Number of degrees of freedom in T-Coupling group Water_and_ions is 81819.30
# Making dummy/rest group for User1 containing 44449 elements
# Making dummy/rest group for User2 containing 44449 elements
# Making dummy/rest group for Compressed X containing 44449 elements
# Making dummy/rest group for Or. Res. Fit containing 44449 elements
# Making dummy/rest group for QMMM containing 44449 elements
# T-Coupling       has 2 element(s): Protein Water_and_ions
# Energy Mon.      has 1 element(s): rest
# Acc. not used    has 1 element(s): rest
# Freeze           has 1 element(s): rest
# User1            has 1 element(s): rest
# User2            has 1 element(s): rest
# VCM              has 1 element(s): rest
# Compressed X     has 1 element(s): rest
# Or. Res. Fit     has 1 element(s): rest
# QMMM             has 1 element(s): rest
#
# The largest distance between excluded atoms is 0.439 nm between atom 2366 and 2374
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 310 K
#
# Calculated rlist for 1x1 atom pair-list as 1.234 nm, buffer size 0.034 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# getting data from old trajectory ...
#
# Reading Coordinates, Velocities and Box size from old trajectory
#
# Will read whole trajectory
# Last frame         -1 time  500.000
#
# Using frame at t = 500 ps
#
# Starting time for run is 0 ps
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 72x72x72, spacing 0.118 0.118 0.118
#
# Estimate for the relative computational load of the PME mesh part: 0.19
#
# This run will generate roughly 14 Mb of data
#
# writing run input file...
#
# GROMACS reminds you: "The Poodle Bites" (F. Zappa)
#
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx mdrun -v -deffnm 3W1C_A_NPT -s 3W1C_A_NPT.tpr -gpu_id 0
#
# Reading file 3W1C_A_NPT.tpr, VERSION 2024.2 (single precision)
# Changing nstlist from 10 to 100, rlist from 1.2 to 1.358
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 2 GPU tasks in the 1 rank on this node:
#   PP:0,PME:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the GPU
# PME tasks will do all aspects on the GPU
# Using 1 MPI thread
# Using 12 OpenMP threads
#
# starting mdrun 'Guyana Rwanda Oman Macau Angola Cameroon Senegal in water'
# 250000 steps,    500.0 ps.
# step 13800: timed with pme grid 72 72 72, coulomb cutoff 1.200: 127.5 M-cycles
# step 14000: timed with pme grid 60 60 60, coulomb cutoff 1.412: 131.5 M-cycles
# step 14200: timed with pme grid 52 52 52, coulomb cutoff 1.629: 159.6 M-cycles
# step 14400: timed with pme grid 56 56 56, coulomb cutoff 1.513: 131.1 M-cycles
# step 14600: timed with pme grid 60 60 60, coulomb cutoff 1.412: 126.8 M-cycles
# step 14800: timed with pme grid 64 64 64, coulomb cutoff 1.323: 121.3 M-cycles
# step 15000: timed with pme grid 72 72 72, coulomb cutoff 1.200: 115.5 M-cycles
# step 15200: timed with pme grid 60 60 60, coulomb cutoff 1.412: 129.0 M-cycles
# step 15400: timed with pme grid 64 64 64, coulomb cutoff 1.323: 142.1 M-cycles
# step 15600: timed with pme grid 72 72 72, coulomb cutoff 1.200: 120.7 M-cycles
#               optimal pme grid 72 72 72, coulomb cutoff 1.200
# step 249900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 250000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     1121.258       93.441     1200.0
#                  (ns/day)    (hour/ns)
# Performance:      462.327        0.052
#
# GROMACS reminds you: "These Gromacs Guys Really Rock" (P.J. Meulenhoff)

# %%
NPT_EDR = Path(f"{NPT_NN}.edr")
NPT_XVG = Path(f"{NPT_NN}.xvg")
# !cd {WD} && echo "Pressure" | gmx energy -f {NPT_EDR} -o {NPT_XVG} -xvg none

fig, ax = plt.subplots(figsize=(3, 3))
df = pd.read_csv(WD / NPT_XVG, sep='\s+', header=None, names=['time', 'pressure'])
df['pressure_avg'] = df['pressure'].rolling(window=5).mean()
plt.plot(df["time"], df["pressure"], color="black", label='10-ps avg')
plt.plot(df["time"], df["pressure_avg"], color="red", linestyle='-', label='50-ps avg')
plt.axhline(y=1, color='black', linestyle='--', linewidth=0.8)
plt.xlabel("time (ps)")
plt.ylabel("pressure (bar)")
plt.legend(loc="lower right")
plt.grid(False)
plt.show()
# Out:
#                       :-) GROMACS - gmx energy, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx energy -f 3W1C_A_NPT.edr -o 3W1C_A_NPT.xvg -xvg none
#
# Opened 3W1C_A_NPT.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pressure
#  17  Constr.-rmsd    18  Box-X           19  Box-Y           20  Box-Z
#  21  Volume          22  Density         23  pV              24  Enthalpy
#  25  Vir-XX          26  Vir-XY          27  Vir-XZ          28  Vir-YX
#  29  Vir-YY          30  Vir-YZ          31  Vir-ZX          32  Vir-ZY
#  33  Vir-ZZ          34  Pres-XX         35  Pres-XY         36  Pres-XZ
#  37  Pres-YX         38  Pres-YY         39  Pres-YZ         40  Pres-ZX
#  41  Pres-ZY         42  Pres-ZZ         43  #Surf*SurfTen   44  T-Protein
#  45  T-Water_and_ions                    46  Lamb-Protein
#  47  Lamb-Water_and_ions
#
# Last energy frame read 50 time  500.000
#
# Statistics over 250001 steps [ 0.0000 through 500.0000 ps ], 1 data sets
# All statistics are over 2501 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                   -4.55797        3.6    143.804    3.51429  (bar)
#
# GROMACS reminds you: "These Gromacs Guys Really Rock" (P.J. Meulenhoff)

# %%
NPT_EDR = Path(f"{NPT_NN}.edr")
NPT_XVG = Path(f"{NPT_NN}_dens.xvg")
# !cd {WD} && echo "Density" | gmx energy -f {NPT_EDR} -o {NPT_XVG} -xvg none

fig, ax = plt.subplots(figsize=(3, 3))
df = pd.read_csv(WD / NPT_XVG, sep='\s+', header=None, names=['time', 'density'])
df['density_avg'] = df['density'].rolling(window=5).mean()
plt.plot(df["time"], df["density"], color="black", label='10-ps avg')
plt.plot(df["time"], df["density_avg"], color="red", linestyle='-', label='50-ps avg')
plt.xlabel("time (ps)")
plt.ylabel("density (kg/m$^{3}$)")
plt.ylim((990, 1060))
plt.legend(loc="lower right")
plt.grid(False)
plt.show()
# Out:
#                       :-) GROMACS - gmx energy, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx energy -f 3W1C_A_NPT.edr -o 3W1C_A_NPT_dens.xvg -xvg none
#
# Opened 3W1C_A_NPT.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pressure
#  17  Constr.-rmsd    18  Box-X           19  Box-Y           20  Box-Z
#  21  Volume          22  Density         23  pV              24  Enthalpy
#  25  Vir-XX          26  Vir-XY          27  Vir-XZ          28  Vir-YX
#  29  Vir-YY          30  Vir-YZ          31  Vir-ZX          32  Vir-ZY
#  33  Vir-ZZ          34  Pres-XX         35  Pres-XY         36  Pres-XZ
#  37  Pres-YX         38  Pres-YY         39  Pres-YZ         40  Pres-ZX
#  41  Pres-ZY         42  Pres-ZZ         43  #Surf*SurfTen   44  T-Protein
#  45  T-Water_and_ions                    46  Lamb-Protein
#  47  Lamb-Water_and_ions
#
# Last energy frame read 50 time  500.000
#
# Statistics over 250001 steps [ 0.0000 through 500.0000 ps ], 1 data sets
# All statistics are over 2501 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                     1029.24       0.21    3.61199    1.23049  (kg/m^3)
#
# GROMACS reminds you: "These Gromacs Guys Really Rock" (P.J. Meulenhoff)

# %% [markdown]
# ## Production
#
# Perform a production simulation under NPT conditions to gather dynamic data about the system.
# The goal is to simulate the behavior of the solvated and neutralized protein in an environment that mimics physiological conditions.
#
# This phase collects detailed molecular dynamics data on the behavior of the protein and its surrounding solvent molecules under conditions that closely mimic a natural, physiological environment.
#
# Running the simulation under constant pressure and temperature ensures that the system's volume can adjust dynamically, providing a more realistic representation of biological conditions.
#
# The data obtained from this production run can be used to analyze various aspects of the protein's behavior, such as conformational changes, stability, interactions with solvent molecules, and other dynamic properties.

# %%
PROD_MDP = Path(GROMACS_PATH) / "prod.mdp"
NPT_GRO = Path(f"{NPT_NN}.gro")
NPT_CPT = Path(f"{NPT_NN}.cpt")
PROD_NN = f"{PROTEIN_PDB.stem}_PROD"
PROD_TPR = Path(f"{PROD_NN}.tpr")
# !cd {WD} && gmx grompp -v -f {PROD_MDP} -c {NPT_GRO} -t {NPT_CPT} -p {PROTEIN_TOP} -o {PROD_TPR}
# !cd {WD} && gmx mdrun -v -deffnm {PROD_NN} -s {PROD_TPR} -gpu_id 0
# Out:
#                       :-) GROMACS - gmx grompp, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx grompp -v -f /home/tz365/WS/ProtMatch/gromacs/prod.mdp -c 3W1C_A_NPT.gro -t 3W1C_A_NPT.cpt -p 3W1C_A.top -o 3W1C_A_PROD.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
# checking input for internal consistency...
#
# Setting the LD random seed to 1207417783
#
# processing topology...
#
# Generated 167799 of the 167910 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 117432 of the 167910 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'NA'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'CL'
#
# turning H bonds into constraints...
#
# processing coordinates...
#
# double-checking input for internal consistency...
# renumbering atomtypes...
#
# converting bonded parameters...
#
# initialising group options...
# processing index file...
# Analysing residue names:
# There are:   228    Protein residues
# There are: 13592      Water residues
# There are:    90        Ion residues
# Analysing Protein...
# Making dummy/rest group for Acc. not used containing 44449 elements
# Making dummy/rest group for Freeze containing 44449 elements
# Making dummy/rest group for Energy Mon. containing 44449 elements
# Making dummy/rest group for VCM containing 44449 elements
# Number of degrees of freedom in T-Coupling group Protein is 8979.70
# Number of degrees of freedom in T-Coupling group Water_and_ions is 81819.30
# Making dummy/rest group for User1 containing 44449 elements
# Making dummy/rest group for User2 containing 44449 elements
# Making dummy/rest group for Compressed X containing 44449 elements
# Making dummy/rest group for Or. Res. Fit containing 44449 elements
# Making dummy/rest group for QMMM containing 44449 elements
# T-Coupling       has 2 element(s): Protein Water_and_ions
# Energy Mon.      has 1 element(s): rest
# Acc. not used    has 1 element(s): rest
# Freeze           has 1 element(s): rest
# User1            has 1 element(s): rest
# User2            has 1 element(s): rest
# VCM              has 1 element(s): rest
# Compressed X     has 1 element(s): rest
# Or. Res. Fit     has 1 element(s): rest
# QMMM             has 1 element(s): rest
#
# The largest distance between excluded atoms is 0.425 nm between atom 1131 and 1139
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 310 K
#
# Calculated rlist for 1x1 atom pair-list as 1.235 nm, buffer size 0.035 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# getting data from old trajectory ...
#
# Reading Coordinates, Velocities and Box size from old trajectory
#
# Will read whole trajectory
# Last frame         -1 time  500.000
#
# Using frame at t = 500 ps
#
# Starting time for run is 0 ps
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 72x72x72, spacing 0.115 0.115 0.115
#
# Estimate for the relative computational load of the PME mesh part: 0.19
#
# This run will generate roughly 220 Mb of data
#
# writing run input file...
#
# GROMACS reminds you: "It's Unacceptable That Chocolate Makes You Fat" (MI 3)
#
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx mdrun -v -deffnm 3W1C_A_PROD -s 3W1C_A_PROD.tpr -gpu_id 0
#
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Changing nstlist from 10 to 100, rlist from 1.2 to 1.363
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 2 GPU tasks in the 1 rank on this node:
#   PP:0,PME:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the GPU
# PME tasks will do all aspects on the GPU
# Using 1 MPI thread
# Using 12 OpenMP threads
#
# starting mdrun 'Guyana Rwanda Oman Macau Angola Cameroon Senegal in water'
# 5000000 steps,  10000.0 ps.
# step 14500: timed with pme grid 72 72 72, coulomb cutoff 1.200: 125.7 M-cycles
# step 14700: timed with pme grid 60 60 60, coulomb cutoff 1.384: 127.9 M-cycles
# step 14900: timed with pme grid 52 52 52, coulomb cutoff 1.597: 153.4 M-cycles
# step 15100: timed with pme grid 56 56 56, coulomb cutoff 1.483: 131.7 M-cycles
# step 15300: timed with pme grid 60 60 60, coulomb cutoff 1.384: 123.8 M-cycles
# step 15500: timed with pme grid 64 64 64, coulomb cutoff 1.297: 123.7 M-cycles
# step 15700: timed with pme grid 72 72 72, coulomb cutoff 1.200: 115.9 M-cycles
# step 15900: timed with pme grid 60 60 60, coulomb cutoff 1.384: 128.9 M-cycles
# step 16100: timed with pme grid 64 64 64, coulomb cutoff 1.297: 118.2 M-cycles
# step 16300: timed with pme grid 72 72 72, coulomb cutoff 1.200: 111.7 M-cycles
# step 16500: timed with pme grid 60 60 60, coulomb cutoff 1.384: 127.3 M-cycles
# step 16700: timed with pme grid 64 64 64, coulomb cutoff 1.297: 114.9 M-cycles
# step 16900: timed with pme grid 72 72 72, coulomb cutoff 1.200: 123.4 M-cycles
# step 17100: timed with pme grid 60 60 60, coulomb cutoff 1.384: 122.7 M-cycles
# step 17300: timed with pme grid 64 64 64, coulomb cutoff 1.297: 115.5 M-cycles
# step 17500: timed with pme grid 72 72 72, coulomb cutoff 1.200: 119.6 M-cycles
#               optimal pme grid 72 72 72, coulomb cutoff 1.200
# step 4999900, remaining wall clock time:     0 s          inish Sat Oct 26 11:34:28 2024, will finish Sat Oct 26 11:34:34 2024, will finish Sat Oct 26 11:34:35 2024, will finish Sat Oct 26 11:34:34 20244270000, remaining wall clock time:   258 s
# Writing final coordinates.
# step 5000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:    21249.561     1770.801     1200.0
#                  (ns/day)    (hour/ns)
# Performance:      487.915        0.049
#
# GROMACS reminds you: "There are only two things wrong with C++:  The initial concept and the implementation." (Bertrand Meyer)

# %%
# !rm -rf {WD}/charmm36-nov2016.ff

# %% [markdown]
# Now, convert some trajectories to PDB for subsequent analysis (ie. phylogenetic tree confidence).

# %%
# !cd {WD} && gmx check -f {NPT_NN}.xtc
# Out:
#                       :-) GROMACS - gmx check, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx check -f 3W1C_A_NPT.xtc
#
# Checking file 3W1C_A_NPT.xtc
# Reading frame       0 time    0.000
# # Atoms  44449
# Precision 0.001 (nm)
# Last frame         50 time  500.000
#
#
# Item        #frames Timestep (ps)
# Step            51    10
# Time            51    10
# Lambda           0
# Coords          51    10
# Velocities       0
# Forces           0
# Box             51    10
#
# GROMACS reminds you: "All creative people want to do the unexpected" (Hedy Lamarr)

# %%
MAX_TIME = 200  # You can get this from the previous command.
os.mkdir(WD / "trajectories")
for i, t in enumerate(range(0, MAX_TIME, 10)):
    # !cd {WD} && echo "Protein" | gmx trjconv -s {PROD_TPR} -f {PROD_NN}.xtc -o trajectories/trj{i}.pdb -dump {t}
# Out:
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj0.pdb -dump 0
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame       1 time   10.000
# Dumping frame at t= 0 ps
#  ->  frame      0 time    0.000
# Last written: frame      0 time    0.000
#
#
# GROMACS reminds you: "All creative people want to do the unexpected" (Hedy Lamarr)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj1.pdb -dump 10
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame       2 time   20.000
# Dumping frame at t= 10 ps
#  ->  frame      0 time   10.000
# Last written: frame      0 time   10.000
#
#
# GROMACS reminds you: "All creative people want to do the unexpected" (Hedy Lamarr)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj2.pdb -dump 20
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame       3 time   30.000
# Dumping frame at t= 20 ps
#  ->  frame      0 time   20.000
# Last written: frame      0 time   20.000
#
#
# GROMACS reminds you: "All creative people want to do the unexpected" (Hedy Lamarr)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj3.pdb -dump 30
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame       4 time   40.000
# Dumping frame at t= 30 ps
#  ->  frame      0 time   30.000
# Last written: frame      0 time   30.000
#
#
# GROMACS reminds you: "All creative people want to do the unexpected" (Hedy Lamarr)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj4.pdb -dump 40
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame       5 time   50.000
# Dumping frame at t= 40 ps
#  ->  frame      0 time   40.000
# Last written: frame      0 time   40.000
#
#
# GROMACS reminds you: "All creative people want to do the unexpected" (Hedy Lamarr)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj5.pdb -dump 50
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame       6 time   60.000
# Dumping frame at t= 50 ps
#  ->  frame      0 time   50.000
# Last written: frame      0 time   50.000
#
#
# GROMACS reminds you: "All creative people want to do the unexpected" (Hedy Lamarr)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj6.pdb -dump 60
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame       7 time   70.000
# Dumping frame at t= 60 ps
#  ->  frame      0 time   60.000
# Last written: frame      0 time   60.000
#
#
# GROMACS reminds you: "Nada e organico, e tudo programado" (Pitty)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj7.pdb -dump 70
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame       8 time   80.000
# Dumping frame at t= 70 ps
#  ->  frame      0 time   70.000
# Last written: frame      0 time   70.000
#
#
# GROMACS reminds you: "Nada e organico, e tudo programado" (Pitty)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj8.pdb -dump 80
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame       9 time   90.000
# Dumping frame at t= 80 ps
#  ->  frame      0 time   80.000
# Last written: frame      0 time   80.000
#
#
# GROMACS reminds you: "Nada e organico, e tudo programado" (Pitty)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj9.pdb -dump 90
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame      10 time  100.000
# Dumping frame at t= 90 ps
#  ->  frame      0 time   90.000
# Last written: frame      0 time   90.000
#
#
# GROMACS reminds you: "Nada e organico, e tudo programado" (Pitty)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj10.pdb -dump 100
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame      11 time  110.000
# Dumping frame at t= 100 ps
#  ->  frame      0 time  100.000
# Last written: frame      0 time  100.000
#
#
# GROMACS reminds you: "Nada e organico, e tudo programado" (Pitty)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj11.pdb -dump 110
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame      12 time  120.000
# Dumping frame at t= 110 ps
#  ->  frame      0 time  110.000
# Last written: frame      0 time  110.000
#
#
# GROMACS reminds you: "Nada e organico, e tudo programado" (Pitty)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj12.pdb -dump 120
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame      13 time  130.000
# Dumping frame at t= 120 ps
#  ->  frame      0 time  120.000
# Last written: frame      0 time  120.000
#
#
# GROMACS reminds you: "Nada e organico, e tudo programado" (Pitty)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj13.pdb -dump 130
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame      14 time  140.000
# Dumping frame at t= 130 ps
#  ->  frame      0 time  130.000
# Last written: frame      0 time  130.000
#
#
# GROMACS reminds you: "Nada e organico, e tudo programado" (Pitty)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj14.pdb -dump 140
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame      15 time  150.000
# Dumping frame at t= 140 ps
#  ->  frame      0 time  140.000
# Last written: frame      0 time  140.000
#
#
# GROMACS reminds you: "As we all know, blinking lights means science." (Joss Whedon)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj15.pdb -dump 150
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame      16 time  160.000
# Dumping frame at t= 150 ps
#  ->  frame      0 time  150.000
# Last written: frame      0 time  150.000
#
#
# GROMACS reminds you: "As we all know, blinking lights means science." (Joss Whedon)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj16.pdb -dump 160
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame      17 time  170.000
# Dumping frame at t= 160 ps
#  ->  frame      0 time  160.000
# Last written: frame      0 time  160.000
#
#
# GROMACS reminds you: "As we all know, blinking lights means science." (Joss Whedon)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj17.pdb -dump 170
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame      18 time  180.000
# Dumping frame at t= 170 ps
#  ->  frame      0 time  170.000
# Last written: frame      0 time  170.000
#
#
# GROMACS reminds you: "As we all know, blinking lights means science." (Joss Whedon)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj18.pdb -dump 180
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame      19 time  190.000
# Dumping frame at t= 180 ps
#  ->  frame      0 time  180.000
# Last written: frame      0 time  180.000
#
#
# GROMACS reminds you: "As we all know, blinking lights means science." (Joss Whedon)
#
#                      :-) GROMACS - gmx trjconv, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx trjconv -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o trajectories/trj19.pdb -dump 190
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for output
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of 3W1C_A_PROD.xtc is 0.001 (nm)
# Reading frame      20 time  200.000
# Dumping frame at t= 190 ps
#  ->  frame      0 time  190.000
# Last written: frame      0 time  190.000
#
#
# GROMACS reminds you: "As we all know, blinking lights means science." (Joss Whedon)

# %% [markdown]
# ## Stability Evaluation

# %%
# os.environ['PATH'] = '/usr/local/gromacs/bin:' + os.environ['PATH']
# 
# PROTEIN_CLS = "BLDB"
# PROTEIN_SID = "SM_12"
# assert PROTEIN_CLS is not None
# assert PROTEIN_SID is not None
# PROTEIN_PDB = Path(f"../data/{PROTEIN_CLS}/generated/BQSH/{PROTEIN_SID}.pdb")
# 
# # Create a new working directory!
# WD = Path(f"MD1/{PROTEIN_CLS}/{PROTEIN_SID}")
# assert WD.exists()
# 
# PROD_NN = f"{PROTEIN_PDB.stem}_PROD"
# PROD_TPR = Path(f"{PROD_NN}.tpr")

# %% [markdown]
# ### RMSD
#
# Calculate the Root Mean Square Deviation (RMSD) of a molecular dynamics trajectory.
# RMSD measures the average deviation of a set of atomic positions from a reference structure, which is the initial structure.
#
# Here, we only calculate RMSD for Backbone (group 4).
#
# 1. **Low RMSD Values (0.1 - 0.3 nm or 1 - 3 $\mathring{\text{A}}$)**: The protein structure is very stable.
#
# 2. **Moderate RMSD Values (0.3 - 0.5 nm or 3 - 5 $\mathring{\text{A}}$)**: The protein structure is reasonably stable with some flexibility.
#
# 3. **High RMSD Values (>0.5 nm or >5 $\mathring{\text{A}}$)**: The protein structure may be unstable.
#
# Regardless of the absolute RMSD value, a key indicator of stability is how the RMSD evolves over time.
# A stable protein will show an initial rise in RMSD as it equilibrates and then plateau, indicating it has reached a stable conformation.
#  Once the RMSD reaches a steady state and fluctuates within a narrow range, the protein can be considered stable.
#  The exact RMSD value at the plateau will depend on the protein and the simulation conditions.

# %%
PROD_XTC = Path(f"{PROD_NN}.xtc")
RMSD_OUT_XVG = Path("RMSD.xvg")
# !cd {WD} && echo "4 4" | gmx rms -s {PROD_TPR} -f {PROD_XTC} -o {RMSD_OUT_XVG} -tu ns
# Out:
#                        :-) GROMACS - gmx rms, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx rms -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o RMSD.xvg -tu ns
#
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group for least squares fit
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 4: 'Backbone'
# Select group for RMSD calculation
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 4: 'Backbone'
# Last frame       1000 time   10.000
#
# GROMACS reminds you: "I Do It All the Time" (Magnapop)

# %%
def read_xvg(file_path, columns):
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            if not line.startswith(('@', '#')):  # Skip header lines
                data.append([float(x) for x in line.split()])
    return pd.DataFrame(data, columns=columns)

# %%
rmsd_df_columns = ["Time (ns)", "RMSD (nm)"]
rmsd_df = read_xvg(WD / RMSD_OUT_XVG, columns=rmsd_df_columns)
plt.figure(figsize=(3, 3))
plt.plot(rmsd_df[rmsd_df_columns[0]], rmsd_df[rmsd_df_columns[1]], label='RMSD', color="black")
plt.plot(rmsd_df[rmsd_df_columns[0]],
         rmsd_df[rmsd_df_columns[1]].rolling(window=200).mean(),
         label='0.1-ns avg', color="red")
plt.xlabel(rmsd_df_columns[0])
plt.ylabel(rmsd_df_columns[1])
plt.title('RMSD')
plt.grid(False)
plt.legend()
plt.show()
print(f"{np.mean(rmsd_df[rmsd_df_columns[1]])} pm {np.std(rmsd_df[rmsd_df_columns[1]])}")
# Out:
# 0.13048516303696306 pm 0.024060599507409953

# %% [markdown]
# ### RMSF
#
# Calculate the Root Mean Square Fluctuation (RMSF) of the atoms or residues in a molecular dynamics (MD) simulation.
#
# By calculating RMSF, wecan identify which parts of the protein (or other macromolecule) are more flexible or dynamic. Regions with high RMSF values are more flexible, whereas regions with low RMSF values are more rigid.
#
# The formula for RMSF is:
# $$
# \text{RMSF}(i) = \sqrt{\frac{1}{N} \sum_{t=1}^{N} (r_i(t) - \langle r_i \rangle)^2}
# $$
#
# 1. **Low RMSF Values**: Regions of the protein with low RMSF values are relatively stable and do not deviate much from their average positions. These stable regions often correspond to secondary structures like alpha-helices and beta-sheets, which maintain their conformation throughout the simulation.
#
# 2. **High RMSF Values**: High RMSF values indicate flexible or dynamic regions that move significantly during the simulation. These regions can correspond to loops, termini, or other flexible parts of the protein.

# %%
RMSF_OUT_XVG = Path("RMSF.xvg")
# !cd {WD} && echo "4" | gmx rmsf -s {PROD_TPR} -f {PROD_XTC} -o {RMSF_OUT_XVG} -res
# Out:
#                        :-) GROMACS - gmx rmsf, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx rmsf -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o RMSF.xvg -res
#
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Select group(s) for root mean square calculation
# Group     0 (         System) has 44449 elements
# Group     1 (        Protein) has  3583 elements
# Group     2 (      Protein-H) has  1814 elements
# Group     3 (        C-alpha) has   228 elements
# Group     4 (       Backbone) has   684 elements
# Group     5 (      MainChain) has   911 elements
# Group     6 (   MainChain+Cb) has  1118 elements
# Group     7 (    MainChain+H) has  1131 elements
# Group     8 (      SideChain) has  2452 elements
# Group     9 (    SideChain-H) has   903 elements
# Group    10 (    Prot-Masses) has  3583 elements
# Group    11 (    non-Protein) has 40866 elements
# Group    12 (          Water) has 40776 elements
# Group    13 (            SOL) has 40776 elements
# Group    14 (      non-Water) has  3673 elements
# Group    15 (            Ion) has    90 elements
# Group    16 ( Water_and_ions) has 40866 elements
# Select a group: Selected 4: 'Backbone'
# Last frame       1000 time 10000.000
#
# GROMACS reminds you: "I never thought about breaking barriers, I was just interested in what I was doing and kept going." (Barbara Liskov)

# %%
rmsf_df_columns = ["Residue", "RMSF (nm)"]
rmsf_df = read_xvg(WD / RMSF_OUT_XVG, columns=rmsf_df_columns)
plt.figure(figsize=(3, 3))
plt.plot(rmsf_df[rmsf_df_columns[0]], rmsf_df[rmsf_df_columns[1]], label='RMSF', color="black")
plt.axhline(y=np.mean(rmsf_df[rmsf_df_columns[1]]), color="red", label="avg", linestyle="--")
plt.xlabel(rmsf_df_columns[0])
plt.ylabel(rmsf_df_columns[1])
plt.legend()
plt.title('RMSF')
plt.grid(False)
plt.show()
print(f"{np.mean(rmsf_df[rmsf_df_columns[1]])} pm {np.std(rmsf_df[rmsf_df_columns[1]])}")
# Out:
# 0.07717192982456139 pm 0.059926037027486105

# %% [markdown]
# ### Radius of Gyration, Rg
#
# Calculate the radius of gyration of a molecule throughout the MD simulation. The radius of gyration is a measure of the distribution of the mass of the molecule around its center of mass. A stable Rg value indicates that the protein is maintaining its overall shape and not unfolding or collapsing.

# %%
RG_OUT_XVG = Path("RG.xvg")
# !cd {WD} && echo "4" | gmx gyrate -s {PROD_TPR} -f {PROD_XTC} -o {RG_OUT_XVG}
# Out:
#                       :-) GROMACS - gmx gyrate, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx gyrate -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o RG.xvg
#
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Last frame       1000 time 10000.000
# Analyzed 1001 frames, last time 10000.000
#
# GROMACS reminds you: "There is nothing new to be discovered in physics now. All that remains is more and more precise measurement." (Lord Kelvin, 1900)

# %%
rg_df_columns = ["Time (ps)", "$R_g$", "$R_g$/sX/N", "$R_g$/sY/N", "$R_g$/sZ/N"]
rg_df = read_xvg(WD / RG_OUT_XVG, columns=rg_df_columns)
plt.figure(figsize=(3, 3))
for i in range(1, len(rg_df_columns)):
    plt.plot(rg_df[rg_df_columns[0]], rg_df[rg_df_columns[i]], label=rg_df_columns[i])
    print(f"{np.mean(rg_df[rg_df_columns[i]])} pm {np.std(rg_df[rg_df_columns[i]])}")
    # plt.plot(rg_df[rg_df_columns[0]], 
    #          rg_df[rg_df_columns[i]].rolling(window=200).mean())
plt.xlabel('Time (ps)')
plt.ylabel('Radius (nm)')
plt.title('$R_g$')
# plt.legend(loc='right', bbox_to_anchor=(1.52, 0.5))
plt.legend(loc='lower right')
plt.grid(False)
# plt.ylim((0, 1.5))
plt.show()
# Out:
# 1.7151050809190809 pm 0.0053957636915112316
# 1.4033853406593404 pm 0.06479049991478401
# 1.3712508221778221 pm 0.0630742360614824
# 1.4214016183816185 pm 0.06965058494963552

# %% [markdown]
# ### Secondary Structure Count
#
# Track changes in its secondary structure elements, such as alpha-helices and beta-sheets. How the overall secondary structure composition of the protein changes during the simulation?
#
# If the number of residues in helices, sheets, or other structures remains relatively constant, it indicates structural stability.

# %%
DSSP_OUT_XVG = Path("DSSP.xvg")
# !cd {WD} && gmx dssp -s {PROD_TPR} -f {PROD_XTC} -o {DSSP_OUT_XVG.stem}.dat -num {DSSP_OUT_XVG} -hmode dssp -clear
# Out:
#                        :-) GROMACS - gmx dssp, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx dssp -s 3W1C_A_PROD.tpr -f 3W1C_A_PROD.xtc -o DSSP.dat -num DSSP.xvg -hmode dssp -clear
#
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Reading file 3W1C_A_PROD.tpr, VERSION 2024.2 (single precision)
# Last frame       1000 time 10000.000
# Analyzed 1001 frames, last time 10000.000
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# W. Kabsch, C. Sander
# Dictionary of protein secondary structure: pattern recognition of
# hydrogen-bonded and geometrical features.
# Biopolymers 22 (1983) pp. 2577-2637
# -------- -------- --- Thank You --- -------- --------
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# S. Gorelov, A. Titov, O. Tolicheva, A. Konevega, A. Shvetsov
# DSSP in GROMACS: Tool for Defining Secondary Structures of Proteins in
# Trajectories
# Journal of Chemical Information and Modeling 0 (2024) pp. 0
# -------- -------- --- Thank You --- -------- --------
#
#
# GROMACS reminds you: "If I have not seen as far as others, it is because giants were standing on my shoulders." (Hal Abelson)

# %%
dssp_df_columns = ["Time (ps)", "Loops", "Breaks", "Bends", "Turns", "PP_Helices", "$\\pi$-Helices", "$3_{10}$-Helices",
                   "$\\beta$-Strands", "$\\beta$-Bridges", "$\\alpha$-Helices"]
dssp_df = read_xvg(WD / DSSP_OUT_XVG, columns=dssp_df_columns)
plt.figure(figsize=(3, 3))
for i in range(1, len(dssp_df_columns)):
    plt.plot(dssp_df[dssp_df_columns[0]], dssp_df[dssp_df_columns[i]], label=dssp_df_columns[i])
    print(f"{np.mean(dssp_df[dssp_df_columns[i]])} pm {np.std(dssp_df[dssp_df_columns[i]])}")
plt.xlabel('Time (ps)')
plt.ylabel('Secondary Structures Count')
plt.title('Secondary Structure')
plt.legend(loc='right', bbox_to_anchor=(1.6, 0.5))
plt.grid(False)
plt.show()
# Out:
# 37.354645354645356 pm 3.81111221597817
# 0.0 pm 0.0
# 22.92207792207792 pm 2.918459297857144
# 31.15884115884116 pm 3.915917497330402
# 1.867132867132867 pm 1.7436422749365066
# 0.03996003996003996 pm 0.4452003987044413
# 8.45854145854146 pm 2.8464762502936924
# 112.7942057942058 pm 2.016318638696184
# 2.976023976023976 pm 0.36781691932051563
# 9.428571428571429 pm 3.4216129853800163

# %% [markdown]
# ### Energy Analysis

# %%
PROD_EDR = Path(f"{PROD_NN}.edr")

# %%
TOTAL_ENERGY_XVG = Path(f"{PROD_NN}_total_energy.xvg")
# !cd {WD} && echo "Total-Energy" | gmx energy -f {PROD_EDR} -o {TOTAL_ENERGY_XVG} -xvg none

POTENTIAL_ENERGY_XVG = Path(f"{PROD_NN}_potential_energy.xvg")
# !cd {WD} && echo "Potential" | gmx energy -f {PROD_EDR} -o {POTENTIAL_ENERGY_XVG} -xvg none

KINETIC_ENERGY_XVG = Path(f"{PROD_NN}_kinetic_energy.xvg")
# !cd {WD} && echo "Kinetic-En." | gmx energy -f {PROD_EDR} -o {KINETIC_ENERGY_XVG} -xvg none
# Out:
#                       :-) GROMACS - gmx energy, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx energy -f 3W1C_A_PROD.edr -o 3W1C_A_PROD_total_energy.xvg -xvg none
#
# Opened 3W1C_A_PROD.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pressure
#  17  Constr.-rmsd    18  Box-X           19  Box-Y           20  Box-Z
#  21  Volume          22  Density         23  pV              24  Enthalpy
#  25  Vir-XX          26  Vir-XY          27  Vir-XZ          28  Vir-YX
#  29  Vir-YY          30  Vir-YZ          31  Vir-ZX          32  Vir-ZY
#  33  Vir-ZZ          34  Pres-XX         35  Pres-XY         36  Pres-XZ
#  37  Pres-YX         38  Pres-YY         39  Pres-YZ         40  Pres-ZX
#  41  Pres-ZY         42  Pres-ZZ         43  #Surf*SurfTen   44  T-Protein
#  45  T-Water_and_ions                    46  Lamb-Protein
#  47  Lamb-Water_and_ions
#
# Last energy frame read 1000 time 10000.000
#
# Statistics over 5000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 50001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Total Energy                -485977         51    1162.98   -349.005  (kJ/mol)
#
# GROMACS reminds you: "It is now quite lawful for a Catholic woman to avoid pregnancy by a resort to mathematics, though she is still forbidden to resort to physics and chemistry." (Henry Louis Mencken)
#
#                       :-) GROMACS - gmx energy, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx energy -f 3W1C_A_PROD.edr -o 3W1C_A_PROD_potential_energy.xvg -xvg none
#
# Opened 3W1C_A_PROD.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pressure
#  17  Constr.-rmsd    18  Box-X           19  Box-Y           20  Box-Z
#  21  Volume          22  Density         23  pV              24  Enthalpy
#  25  Vir-XX          26  Vir-XY          27  Vir-XZ          28  Vir-YX
#  29  Vir-YY          30  Vir-YZ          31  Vir-ZX          32  Vir-ZY
#  33  Vir-ZZ          34  Pres-XX         35  Pres-XY         36  Pres-XZ
#  37  Pres-YX         38  Pres-YY         39  Pres-YZ         40  Pres-ZX
#  41  Pres-ZY         42  Pres-ZZ         43  #Surf*SurfTen   44  T-Protein
#  45  T-Water_and_ions                    46  Lamb-Protein
#  47  Lamb-Water_and_ions
#
# Last energy frame read 1000 time 10000.000
#
# Statistics over 5000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 50001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Potential                   -603002         52    891.637   -360.499  (kJ/mol)
#
# GROMACS reminds you: "It is now quite lawful for a Catholic woman to avoid pregnancy by a resort to mathematics, though she is still forbidden to resort to physics and chemistry." (Henry Louis Mencken)
#
#                       :-) GROMACS - gmx energy, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/tz365/WS/PROTEVAL/notebooks/dynamics/wd-md1/GFP/3W1C_A
# Command line:
#   gmx energy -f 3W1C_A_PROD.edr -o 3W1C_A_PROD_kinetic_energy.xvg -xvg none
#
# Opened 3W1C_A_PROD.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  U-B              3  Proper-Dih.      4  Improper-Dih.
#   5  CMAP-Dih.        6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pressure
#  17  Constr.-rmsd    18  Box-X           19  Box-Y           20  Box-Z
#  21  Volume          22  Density         23  pV              24  Enthalpy
#  25  Vir-XX          26  Vir-XY          27  Vir-XZ          28  Vir-YX
#  29  Vir-YY          30  Vir-YZ          31  Vir-ZX          32  Vir-ZY
#  33  Vir-ZZ          34  Pres-XX         35  Pres-XY         36  Pres-XZ
#  37  Pres-YX         38  Pres-YY         39  Pres-YZ         40  Pres-ZX
#  41  Pres-ZY         42  Pres-ZZ         43  #Surf*SurfTen   44  T-Protein
#  45  T-Water_and_ions                    46  Lamb-Protein
#  47  Lamb-Water_and_ions
#
# Last energy frame read 1000 time 10000.000
#
# Statistics over 5000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 50001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Kinetic En.                  117024          5    616.256    11.4927  (kJ/mol)
#
# GROMACS reminds you: "It is now quite lawful for a Catholic woman to avoid pregnancy by a resort to mathematics, though she is still forbidden to resort to physics and chemistry." (Henry Louis Mencken)

# %%
tot_en_df = pd.read_csv(WD / TOTAL_ENERGY_XVG, sep='\s+', header=None, names=['step', 'Total-Energy'])
pot_en_df = pd.read_csv(WD / POTENTIAL_ENERGY_XVG, sep='\s+', header=None, names=['step', 'Potential-Energy'])
ktc_en_df = pd.read_csv(WD / KINETIC_ENERGY_XVG, sep='\s+', header=None, names=['step', 'Kinetic-Energy'])


print(f"{np.mean(tot_en_df['Total-Energy'])} pm {np.std(tot_en_df['Total-Energy'])}")
print(f"{np.mean(pot_en_df['Potential-Energy'])} pm {np.std(pot_en_df['Potential-Energy'])}")
print(f"{np.mean(ktc_en_df['Kinetic-Energy'])} pm {np.std(ktc_en_df['Kinetic-Energy'])}")

fig, ax = plt.subplots(figsize=(3, 3))
plt.plot(tot_en_df["step"], tot_en_df["Total-Energy"], label="total energy")
plt.plot(pot_en_df["step"], pot_en_df["Potential-Energy"], label="potential energy")
plt.plot(ktc_en_df["step"], ktc_en_df["Kinetic-Energy"], label="kinetic energy")
plt.xlabel("time (ps)")
plt.ylabel("energy (kJ/mol)")
plt.legend()
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))
plt.grid(False)
plt.title("Energy")
plt.show()
# Out:
# -485970.82935814187 pm 1142.6332303962483
# -603024.1562812187 pm 896.7171178268876
# 117053.3267903926 pm 589.9069790080762

# %% [markdown]
# ### Contact Map (Deperated)
#
# A contact map is a 2D matrix where each cell (i, j) represents the contact (usually within a certain distance threshold, like 0.5 nm) between residue i and residue j over the course of the simulation. A high value in a cell indicates frequent contacts between those residues.
#
# **Consistency of Contacts**:
# - **Stable Regions**: Residues that maintain consistent contacts throughout the simulation indicate stable regions of the protein. In the contact map, these appear as persistent spots or clusters of high values.
# - **Unstable Regions**: Regions where contacts are inconsistent or transient indicate flexible or unstable parts of the protein. These regions will show as dispersed or low-value spots in the contact map.

# %%
# CONTACT_XVG = Path("CONTACT.xvg")
# CONTACT_XPM = Path(f"{CONTACT_XVG.stem}.xpm")
# !cd {WD} && echo "4" | gmx mdmat -s {PROD_TPR} -f {PROD_XTC} -mean {CONTACT_XPM} -no {CONTACT_XVG}

# %%
# !cd {WD} && gmx xpm2ps -f {CONTACT_XPM} -o {CONTACT_XPM.stem}.eps
# import matplotlib.image as mpimg
# 
# img = mpimg.imread(WD / f"{CONTACT_XPM.stem}.eps")
# 
# plt.figure(figsize=(2, 2), dpi=300)
# plt.imshow(img)
# plt.axis('off')
# plt.show()
