# %% [markdown]
# # Homology Modelling of Side Chains

# %%
from pathlib import Path

# change accordingly
GENERATED_CLS = GENERATED_CLS if "GENERATED_CLS" in locals() else "BLDB"
GENERATED_SID = GENERATED_SID if "GENERATED_SID" in locals() else "FM_0"
assert GENERATED_CLS is not None
assert GENERATED_SID is not None

MIN_HOMOLOGY = MIN_HOMOLOGY if "MIN_HOMOLOGY" in locals() else 0.35
MIN_TM_SCORE = MIN_TM_SCORE if "MIN_TM_SCORE" in locals() else 0.8
MAX_TEMPLATES = MAX_TEMPLATES if "MAX_TEMPLATES" in locals() else 5
print(
    f"Homology Modelling: {GENERATED_CLS}/{GENERATED_SID}. Min Homology = {MIN_HOMOLOGY}. Maximum Number of Templates to Use = {MAX_TEMPLATES}.")

GENERATED_PDB = Path(f"../../data/{GENERATED_CLS}/generated/BQ/{GENERATED_SID}.pdb")
GENERATED_SEQ = Path(f"../../data/{GENERATED_CLS}/generated/Q/{GENERATED_SID}.fasta")
# Out:
# Homology Modelling: BLDB/FM_0. Min Homology = 0.35. Maximum Number of Templates to Use = 5.

# %% [markdown]
# Identy and select template structures for subsequent homology modelling of side chains.
#
# - Use FoldSeek for sequence + structure alignment.
# - The homology should be at least 70%.
#
# You may wish to increase the limit on the data rate that the notebook server can send to clients and the window size used to compute the average data rate for the limit, by adding the following tags:
#
# ```
# notebook --ServerApp.iopub_data_rate_limit 10000000.0 --ServerApp.rate_limit_window=25.0
# ```

# %%
from time import sleep

from requests import get, post

TICKET_URL = "https://search.foldseek.com/api/ticket"
RESULT_URL = "https://search.foldseek.com/api/result"

# submit a new job
# curl -X POST -F q=@{GEN_PDB} -F 'mode=tmalign' -F 'database[]=pdb100' https://search.foldseek.com/api/ticket
with open(GENERATED_PDB, 'rb') as f:
    ticket = post(
        TICKET_URL,
        files={'q': f},
        data={
            "mode": "tmalign",
            "database[]": "pdb100"
        }).json()
    print("Job submitted:", ticket)

repeat = True
while repeat:
    status = get(f"{TICKET_URL}/{ticket['id']}").json()
    print("Running status:", ticket)
    if status["status"] == "ERROR":
        break
    sleep(1)
    repeat = status["status"] != "COMPLETE"

result = get(f"{RESULT_URL}/{ticket['id']}/0").json()
# import json
# with open("result.json", "w") as json_file:
#     json.dump(result, json_file, indent=4)
result = result["results"][0]["alignments"][0]

visited = set()
templates = [
                {"PDB": pdb,
                 "seq": alignment["tSeq"],
                 "tm-score": alignment["eval"],
                 "prob": alignment["prob"],
                 "seq-per-identity": alignment["seqId"],
                 }
                for alignment in result
                if alignment["seqId"] > MIN_HOMOLOGY
                if alignment["eval"] > MIN_HOMOLOGY
                if (pdb := alignment["target"].split("-")[0].upper()) not in visited and not visited.add(pdb)
                if pdb not in ["6WJM", "6WGP", "2QU1"]
            ][:min(MAX_TEMPLATES, len(result))]
# Out:
# Job submitted: {'id': '3yvS7Hr3b7TyJdzKPW6qfOVSihFBcu9f61DrRA', 'status': 'COMPLETE'}
# Running status: {'id': '3yvS7Hr3b7TyJdzKPW6qfOVSihFBcu9f61DrRA', 'status': 'COMPLETE'}

# %% [markdown]
# Prepare (1) working directory, (2) FASTAs for alignment, (3) PDBs for homology modelling.

# %%
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio import PDB, SeqIO
import shutil

wd = Path(f"wd/{GENERATED_CLS}/{GENERATED_SID}")
wd.mkdir(parents=True, exist_ok=True)

pdb_dir = wd / "pdb"
pdb_dir.mkdir(parents=True, exist_ok=True)

fasta = wd / "seqs.fasta"
fasta_seqs = [SeqIO.read(GENERATED_SEQ, "fasta")]
parser = PDB.PDBParser()

shutil.copy(
    src=GENERATED_PDB,
    dst=pdb_dir / GENERATED_PDB.name
)

for temp in templates:
    temp_id = temp["PDB"]
    for temp_pdb in Path(f"../../data/{GENERATED_CLS}/processed").glob(f"{temp_id}*.pdb"):
        print(f"Template {temp_pdb.stem}")
        shutil.copy(
            src=temp_pdb,
            dst=pdb_dir / temp_pdb.name
        )
        structure = parser.get_structure('structure', temp_pdb)
        sequence = ''
        for model in structure:
            for chain in model:
                for residue in chain:
                    if PDB.is_aa(residue, standard=True):
                        sequence += PDB.Polypeptide.index_to_one(PDB.Polypeptide.three_to_index(residue.resname))
        fasta_seqs.append(SeqRecord(Seq(sequence), id=temp_pdb.stem, description=""))

with open(fasta, "w") as f:
    SeqIO.write(fasta_seqs, f, format="fasta")
# Out:
# Template 8DPQ_A
# Template 8DON_A
# Template 6D7H_A
# Template 6W34_B
# Template 6W34_A
# Template 5TWD_A

# %% [markdown]
# Align sequences using Clustal.

# %%
# !clustalw -infile={fasta} -output=pir

# !clustalo -i {fasta} -o {fasta.parent}/{fasta.stem}.aln.fasta --outfmt=fa
# !seqret -sequence {fasta.parent}/{fasta.stem}.aln.fasta -outseq {fasta.parent}/{fasta.stem}.pir -osformat2 pir

# %% [markdown]
# Fill the missing details in the PIR alignment.

# %%
PIR_RAW = fasta.parent / f"{fasta.stem}.pir"
PIR_REF = PIR_RAW.parent / f"{PIR_RAW.stem}.ref.pir"

entries = []

# l1: >P1;8DOD
# l2: StructureX:8DOD.pdb:26:A:290:::::
# lx: <SEQUENCE>
with open(PIR_RAW, "r") as i, open(PIR_REF, "w") as o:
    entry_id = None
    l2 = False
    for l in i:
        # l1
        if l.startswith(">P1;"):
            entry_id = l[4:].split(" ")[0].strip()
            l2 = True
            o.write(l)
        # l2
        elif l2:
            l2 = False
            chain_id = None
            try:
                chain_id = next(Path(f"../../data/{GENERATED_CLS}/processed").glob(f"{entry_id}*.pdb")).stem.split("_")[-1]
            except StopIteration:
                chain_id = "A"
            start, end = float('inf'), float('-inf')
            for model in parser.get_structure('structure', pdb_dir / f"{entry_id}.pdb"):
                for chain in model:
                    if chain.id != chain_id:
                        continue
                    for residue in chain:
                        if PDB.is_aa(residue, standard=True):
                            start = min(residue.id[1], start)
                            end = max(residue.id[1], start)
            o.write(f"StructureX:{entry_id}.pdb:{start}:{chain_id}:{end}:::::\n")
            entries.append(entry_id)
        # lx
        else:
            o.write(l)

entries.remove(GENERATED_SID)

# %% [markdown]
# Homology modelling of side chains.
# Main chains are fixed.
# Load model from the existing backbone structure.
#
# Model 10 times; select the best one.
#
# You may need to manually edit the data to avoid potential errors.

# %%
# %cd {wd}

from modeller import *
from modeller.automodel import *
from modeller.scripts import *

# log.verbose()
env = Environ()


class SidechainModel(AutoModel):
    def select_atoms(self):
        return Selection(self).only_sidechain()


env.io.atom_files_directory = "./pdb"

a = SidechainModel(
    env,
    alnfile=PIR_REF.name,
    knowns=entries,
    sequence=GENERATED_SID,
    inifile=str(f"./pdb/{GENERATED_PDB.name}")
)
a.starting_model = 1
a.ending_model = 10
a.assess_methods = [assess.DOPE]
a.make()
# Out:
# /home/tz365/miniconda3/envs/protgen/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /home/tz365/WS/ProtMatch/notebooks/HM/BLDB/FM_0
#
#                          MODELLER 10.5, 2024/01/19, r12711
#
#      PROTEIN STRUCTURE MODELLING BY SATISFACTION OF SPATIAL RESTRAINTS
#
#
#                      Copyright(c) 1989-2024 Andrej Sali
#                             All Rights Reserved
#
#                              Written by A. Sali
#                                with help from
#               B. Webb, M.S. Madhusudhan, M-Y. Shen, G.Q. Dong,
#           M.A. Marti-Renom, N. Eswar, F. Alber, M. Topf, B. Oliva,
#              A. Fiser, R. Sanchez, B. Yerkovich, A. Badretdinov,
#                      F. Melo, J.P. Overington, E. Feyfant
#                  University of California, San Francisco, USA
#                     Rockefeller University, New York, USA
#                       Harvard University, Cambridge, USA
#                    Imperial Cancer Research Fund, London, UK
#               Birkbeck College, University of London, London, UK
#
#
# Kind, OS, HostName, Kernel, Processor: 4, Linux 23OCT-4090-70K 5.15.153.1-microsoft-standard-WSL2 x86_64
# Date and time of compilation         : 2024/01/20 00:32:05
# MODELLER executable type             : x86_64-intel8
# Job starting time (YY/MM/DD HH:MM:SS): 2024/10/01 21:03:44
#
# IOData_____W> Setting io.atom_files_directory to a colon-delimited string is
#               deprecated, as it is not robust on Windows systems. Set it to
#               a list of directories instead. For example:
#               env.io.atom_files_directory = ['./pdb']
# readlinef__W> File: ./pdb/8DPQ_A.pdb, Line: 1956
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: ./pdb/8DON_A.pdb, Line: 3868
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: ./pdb/6D7H_A.pdb, Line: 3937
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: ./pdb/6W34_B.pdb, Line: 2045
#               Modeller will only read the first 80 characters of this line.
# readlinef__W> File: ./pdb/6W34_A.pdb, Line: 2036
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: ./pdb/5TWD_A.pdb, Line: 1958
#               Modeller will only read the first 80 characters of this line.
#
#
# check_ali___> Checking pairwise structural superpositions.
#
# Equivalent CA pairs with distance difference larger than  6.0 angstroms:
#
# ALN_POS TMPL1 TMPL2  RID1  RID2  NAM1  NAM2     DIST
# ----------------------------------------------------
#      63     1     4   86   111      T     I    8.369
#      63     1     5   86   111      T     I    8.427
#      63     2     4   86   111      T     I    8.784
#      63     2     5   86   111      T     I    8.837
#      63     3     4   86   111      T     I    8.564
#      63     3     5   86   111      T     I    8.620
#      63     4     6  111    86      I     T    8.717
#      63     5     6  111    86      I     T    8.771
# END OF TABLE
#
# check_ali___> Checking the sequence-structure alignment.
#
# Implied intrachain target CA(i)-CA(i+1) distances longer than  8.0 angstroms:
#
# ALN_POS  TMPL  RID1  RID2  NAM1  NAM2     DIST
# ----------------------------------------------
#      63     1   86    89      K     D    8.902
#      63     2   86    89      K     D    8.787
#      63     3   86    89      K     D    8.695
#      63     6   86    89      K     D    8.879
# END OF TABLE
# read_to_681_> topology.submodel read from topology file:        3
# readlinef__W> File: ./pdb/FM_0.pdb, Line: 1351
#               Modeller will only read the first 80 characters of this line.
# mdtrsr__446W> A potential that relies on one protein is used, yet you have at
#               least one known structure available. MDT, not library, potential is used.
# 0 atoms in HETATM/BLK residues constrained
# to protein atoms within 2.30 angstroms
# and protein CA atoms within 10.00 angstroms
# 0 atoms in residues without defined topology
# constrained to be rigid bodies
# condens_443_> Restraints marked for deletion were removed.
#               Total number of restraints before, now:    26192    24366
# 864 (of 1945 total) atoms selected for optimization
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945     864
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    24366    8038
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   256652
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -15746.8867
#
#
#
#
# << end of ENERGY.
# DOPE score               : -15746.886719
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945     864
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    24366    8038
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     2306
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        4094.9463
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :     888       0      0   0.005   0.005      4.4122       1.000
#  2 Bond angle potential               :    1318       0      9   2.307   2.307      127.96       1.000
#  3 Stereochemical cosine torsion poten:    1099       0     46  52.346  52.346      479.72       1.000
#  4 Stereochemical improper torsion pot:     475       1      2   2.162   2.162      37.598       1.000
#  5 Soft-sphere overlap restraints     :    2306       0      0   0.004   0.004      4.8445       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :       0       0      0   0.000   0.000      0.0000       1.000
# 10 Distance restraints 2 (N-O)        :       0       0      0   0.000   0.000      0.0000       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 14 Sidechain Chi_1 dihedral restraints:     209       0      5  80.254  80.254      80.373       1.000
# 15 Sidechain Chi_2 dihedral restraints:     133       0      3  71.182  71.182      55.061       1.000
# 16 Sidechain Chi_3 dihedral restraints:      57       0      0  67.768  67.768      33.806       1.000
# 17 Sidechain Chi_4 dihedral restraints:      31       0      0  88.725  88.725      23.528       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :    2927       0      4   0.678   0.678      2378.4       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :     901       1     20   1.265   1.265      869.22       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: FM_0.V99990001
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   14846.0557
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
# -------------------------------------------------------------------------------------------------
#
# Feature 26                           : Distance restraints 4 (SDCH-SDCH)
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1  23850  62S  65P OG  CB    457  480   10.79    3.27    7.52    4.77    3.27    7.52    4.77
#
#
# report______> Distribution of short non-bonded contacts:
#
#   serious non-bonded atom clash:   281  297   2.071
#   serious non-bonded atom clash:   506  695   2.116
#   serious non-bonded atom clash:  1044 1047   2.186
#   serious non-bonded atom clash:  1081 1088   1.797
#   serious non-bonded atom clash:  1585 1812   2.173
#   serious non-bonded atom clash:  1587 1812   1.740
#   serious non-bonded atom clash:  1589 1826   2.243
#   serious non-bonded atom clash:  1591 1826   1.744
#   serious non-bonded atom clash:  1591 1827   1.926
#   serious non-bonded atom clash:  1592 1827   2.079
#   serious non-bonded atom clash:  1785 1794   2.188
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     6    4    1    4    4   26   42  115  139  210  218  244  254  293  308
#
#
# << end of ENERGY.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945     864
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    24366    8038
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   256777
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -15692.2100
#
#
#
#
# << end of ENERGY.
# DOPE score               : -15692.209961
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945     864
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    24366    8038
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     2380
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        4011.9414
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :     888       0      0   0.004   0.004      3.6063       1.000
#  2 Bond angle potential               :    1318       1      5   2.047   2.047      104.24       1.000
#  3 Stereochemical cosine torsion poten:    1099       0     47  52.123  52.123      474.90       1.000
#  4 Stereochemical improper torsion pot:     475       1      2   1.922   1.922      29.857       1.000
#  5 Soft-sphere overlap restraints     :    2380       0      0   0.004   0.004      4.4521       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :       0       0      0   0.000   0.000      0.0000       1.000
# 10 Distance restraints 2 (N-O)        :       0       0      0   0.000   0.000      0.0000       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 14 Sidechain Chi_1 dihedral restraints:     209       0      5  83.285  83.285      76.178       1.000
# 15 Sidechain Chi_2 dihedral restraints:     133       0      4  71.213  71.213      49.072       1.000
# 16 Sidechain Chi_3 dihedral restraints:      57       0      0  64.511  64.511      32.078       1.000
# 17 Sidechain Chi_4 dihedral restraints:      31       0      0  76.087  76.087      20.100       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :    2927       0      3   0.630   0.630      2356.0       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :     901       0     18   1.253   1.253      861.46       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: FM_0.V99990002
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   14326.9023
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
#
# report______> Distribution of short non-bonded contacts:
#
#   serious non-bonded atom clash:   281  297   2.071
#   serious non-bonded atom clash:   506  695   2.116
#   serious non-bonded atom clash:  1044 1047   2.186
#   serious non-bonded atom clash:  1081 1088   1.797
#   serious non-bonded atom clash:  1585 1812   2.173
#   serious non-bonded atom clash:  1587 1812   1.740
#   serious non-bonded atom clash:  1589 1826   2.243
#   serious non-bonded atom clash:  1591 1826   1.744
#   serious non-bonded atom clash:  1591 1827   1.926
#   serious non-bonded atom clash:  1592 1827   2.079
#   serious non-bonded atom clash:  1785 1794   2.188
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     6    4    1    4    4   32   48  119  150  191  221  246  283  304  337
#
#
# << end of ENERGY.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945     864
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    24366    8038
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   256884
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -15479.0254
#
#
#
#
# << end of ENERGY.
# DOPE score               : -15479.025391
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945     864
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    24366    8038
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     2388
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        4366.4009
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :     888       0      2   0.008   0.008      14.975       1.000
#  2 Bond angle potential               :    1318       8     13   4.954   4.954      432.03       1.000
#  3 Stereochemical cosine torsion poten:    1099       0     46  52.063  52.063      475.04       1.000
#  4 Stereochemical improper torsion pot:     475       0      2   1.810   1.810      26.707       1.000
#  5 Soft-sphere overlap restraints     :    2388       1      2   0.008   0.008      19.460       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :       0       0      0   0.000   0.000      0.0000       1.000
# 10 Distance restraints 2 (N-O)        :       0       0      0   0.000   0.000      0.0000       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 14 Sidechain Chi_1 dihedral restraints:     209       0      2  82.077  82.077      70.835       1.000
# 15 Sidechain Chi_2 dihedral restraints:     133       0      1  59.876  59.876      44.720       1.000
# 16 Sidechain Chi_3 dihedral restraints:      57       0      0  78.939  78.939      39.464       1.000
# 17 Sidechain Chi_4 dihedral restraints:      31       0      0  84.108  84.108      22.069       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :    2927       0      7   0.651   0.651      2373.5       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :     901       1     16   1.179   1.179      847.63       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: FM_0.V99990003
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   14468.6465
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
# -------------------------------------------------------------------------------------------------
#
# Feature  2                           : Bond angle potential
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1   4345 241F 241F CB  CG   1732 1733  152.31  122.30   30.01    6.52  122.30   30.01    6.52
#
# -------------------------------------------------------------------------------------------------
#
# Feature 26                           : Distance restraints 4 (SDCH-SDCH)
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1  23850  62S  65P OG  CB    457  480   10.79    3.27    7.52    4.77    3.27    7.52    4.77
#
#
# report______> Distribution of short non-bonded contacts:
#
#   serious non-bonded atom clash:   281  297   2.071
#   serious non-bonded atom clash:   506  695   2.116
#   serious non-bonded atom clash:  1044 1047   2.186
#   serious non-bonded atom clash:  1081 1088   1.797
#   serious non-bonded atom clash:  1585 1812   2.173
#   serious non-bonded atom clash:  1587 1812   1.740
#   serious non-bonded atom clash:  1589 1826   2.243
#   serious non-bonded atom clash:  1591 1826   1.744
#   serious non-bonded atom clash:  1591 1827   1.926
#   serious non-bonded atom clash:  1592 1827   2.079
#   serious non-bonded atom clash:  1785 1794   2.188
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     6    4    1    4    4   36   45  127  136  204  218  236  290  316  345
#
#
# << end of ENERGY.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945     864
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    24366    8038
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   255786
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -15626.8965
#
#
#
#
# << end of ENERGY.
# DOPE score               : -15626.896484
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945     864
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    24366    8038
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     2331
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        4014.1733
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :     888       0      0   0.004   0.004      4.1738       1.000
#  2 Bond angle potential               :    1318       1      9   2.214   2.214      120.35       1.000
#  3 Stereochemical cosine torsion poten:    1099       0     46  52.138  52.138      475.36       1.000
#  4 Stereochemical improper torsion pot:     475       0      0   1.788   1.788      25.797       1.000
#  5 Soft-sphere overlap restraints     :    2331       0      0   0.005   0.005      5.8625       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :       0       0      0   0.000   0.000      0.0000       1.000
# 10 Distance restraints 2 (N-O)        :       0       0      0   0.000   0.000      0.0000       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 14 Sidechain Chi_1 dihedral restraints:     209       0      4  78.068  78.068      62.845       1.000
# 15 Sidechain Chi_2 dihedral restraints:     133       0      1  70.517  70.517      45.883       1.000
# 16 Sidechain Chi_3 dihedral restraints:      57       0      0  68.428  68.428      30.780       1.000
# 17 Sidechain Chi_4 dihedral restraints:      31       0      0  89.097  89.097      18.580       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :    2927       0      4   0.658   0.658      2369.6       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :     901       1     14   1.210   1.210      854.94       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: FM_0.V99990004
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   13988.6660
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
# -------------------------------------------------------------------------------------------------
#
# Feature 26                           : Distance restraints 4 (SDCH-SDCH)
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1  23850  62S  65P OG  CB    457  480   10.94    3.27    7.67    4.86    3.27    7.67    4.86
#
#
# report______> Distribution of short non-bonded contacts:
#
#   serious non-bonded atom clash:   281  297   2.071
#   serious non-bonded atom clash:   506  695   2.116
#   serious non-bonded atom clash:  1044 1047   2.186
#   serious non-bonded atom clash:  1081 1088   1.797
#   serious non-bonded atom clash:  1585 1812   2.173
#   serious non-bonded atom clash:  1587 1812   1.740
#   serious non-bonded atom clash:  1589 1826   2.243
#   serious non-bonded atom clash:  1591 1826   1.744
#   serious non-bonded atom clash:  1591 1827   1.926
#   serious non-bonded atom clash:  1592 1827   2.079
#   serious non-bonded atom clash:  1785 1794   2.188
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     6    4    1    4    4   26   44  119  146  190  210  248  265  284  341
#
#
# << end of ENERGY.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_484W> Dihedral still outside +-90:      -92.1871
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945     864
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    24366    8038
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   255663
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -15489.7734
#
#
#
#
# << end of ENERGY.
# DOPE score               : -15489.773438
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945     864
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    24366    8038
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     2371
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        3971.1497
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
# ...
#  4 Stereochemical improper torsion pot:     475       0      0   1.692   1.692      23.084       1.000
#  5 Soft-sphere overlap restraints     :    2383       0      0   0.004   0.004      4.6883       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :       0       0      0   0.000   0.000      0.0000       1.000
# 10 Distance restraints 2 (N-O)        :       0       0      0   0.000   0.000      0.0000       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 14 Sidechain Chi_1 dihedral restraints:     209       0      4  84.499  84.499      85.377       1.000
# 15 Sidechain Chi_2 dihedral restraints:     133       0      2  66.050  66.050      50.864       1.000
# 16 Sidechain Chi_3 dihedral restraints:      57       0      0  61.950  61.950      28.751       1.000
# 17 Sidechain Chi_4 dihedral restraints:      31       0      0  87.868  87.868      20.255       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :    2927       0      3   0.607   0.607      2351.1       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :     901       0     18   1.235   1.235      865.33       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: FM_0.V99990009
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   14325.1475
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
#
# report______> Distribution of short non-bonded contacts:
#
#   serious non-bonded atom clash:   281  297   2.071
#   serious non-bonded atom clash:   506  695   2.116
#   serious non-bonded atom clash:  1044 1047   2.186
#   serious non-bonded atom clash:  1081 1088   1.797
#   serious non-bonded atom clash:  1585 1812   2.173
#   serious non-bonded atom clash:  1587 1812   1.740
#   serious non-bonded atom clash:  1589 1826   2.243
#   serious non-bonded atom clash:  1591 1826   1.744
#   serious non-bonded atom clash:  1591 1827   1.926
#   serious non-bonded atom clash:  1592 1827   2.079
#   serious non-bonded atom clash:  1785 1794   2.188
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     6    4    1    4    4   31   43  130  142  206  224  249  254  306  306
#
#
# << end of ENERGY.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945     864
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    24366    8038
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   256130
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -15542.7637
#
#
#
#
# << end of ENERGY.
# DOPE score               : -15542.763672
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945     864
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    24366    8038
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     2395
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        4041.5107
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :     888       0      0   0.005   0.005      5.3528       1.000
#  2 Bond angle potential               :    1318       1      6   2.136   2.136      112.56       1.000
#  3 Stereochemical cosine torsion poten:    1099       0     45  52.141  52.141      473.12       1.000
#  4 Stereochemical improper torsion pot:     475       0      1   1.892   1.892      29.597       1.000
#  5 Soft-sphere overlap restraints     :    2395       0      0   0.006   0.006      11.589       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :       0       0      0   0.000   0.000      0.0000       1.000
# 10 Distance restraints 2 (N-O)        :       0       0      0   0.000   0.000      0.0000       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 14 Sidechain Chi_1 dihedral restraints:     209       0      3  82.484  82.484      61.059       1.000
# 15 Sidechain Chi_2 dihedral restraints:     133       0      1  70.134  70.134      50.244       1.000
# 16 Sidechain Chi_3 dihedral restraints:      57       0      0  72.287  72.287      36.062       1.000
# 17 Sidechain Chi_4 dihedral restraints:      31       0      0  79.494  79.494      18.117       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :    2927       0      3   0.622   0.622      2351.2       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :     901       0     33   1.329   1.329      892.56       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: FM_0.V99990010
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   14210.5967
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
#
# report______> Distribution of short non-bonded contacts:
#
#   serious non-bonded atom clash:   281  297   2.071
#   serious non-bonded atom clash:   506  695   2.116
#   serious non-bonded atom clash:  1044 1047   2.186
#   serious non-bonded atom clash:  1081 1088   1.797
#   serious non-bonded atom clash:  1585 1812   2.173
#   serious non-bonded atom clash:  1587 1812   1.740
#   serious non-bonded atom clash:  1589 1826   2.243
#   serious non-bonded atom clash:  1591 1826   1.744
#   serious non-bonded atom clash:  1591 1827   1.926
#   serious non-bonded atom clash:  1592 1827   2.079
#   serious non-bonded atom clash:  1785 1794   2.188
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     6    4    1    4    4   35   43  127  140  195  225  247  288  314  322
#
#
# << end of ENERGY.
#
# >> Summary of successfully produced models:
# Filename                          molpdf     DOPE score
# -------------------------------------------------------
# FM_0.B99990001.pdb            4094.94629   -15746.88672
# FM_0.B99990002.pdb            4011.94141   -15692.20996
# FM_0.B99990003.pdb            4366.40088   -15479.02539
# FM_0.B99990004.pdb            4014.17334   -15626.89648
# FM_0.B99990005.pdb            3971.14966   -15489.77344
# FM_0.B99990006.pdb            4039.97314   -15523.64160
# FM_0.B99990007.pdb            3984.40723   -15377.31543
# FM_0.B99990008.pdb            4044.33691   -15496.18359
# FM_0.B99990009.pdb            4014.86963   -15204.42188
# FM_0.B99990010.pdb            4041.51074   -15542.76367

# %% [markdown]
# DOPE is a Z-score.
#
# Positive scores are likely to be poor models, while scores lower than -1 or so are likely to be native-like.
#
# Select the best model with the lowest score.

# %%
import pandas as pd
import os

lowest_dope = float('inf')
best_model = None

scores = pd.DataFrame([
    {"Model": str(model),
     "DOPE Score": complete_pdb(env, str(model)).assess_normalized_dope()
     } for model in Path("./").glob(f"{GENERATED_SID}.B*.pdb")
]).sort_values(by="DOPE Score", ascending=True)
print(scores)

os.rename(scores.iloc[0]['Model'], f"{GENERATED_SID}.best.pdb")
# Out:
# readlinef__W> File: FM_0.B99990001.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945    1945
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   380873
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -24624.5684
#
#
#
#
# << end of ENERGY.
# DOPE score               : -24624.568359
# >> Normalized DOPE z score: -0.765
# readlinef__W> File: FM_0.B99990002.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945    1945
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   380993
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -24569.6973
#
#
#
#
# << end of ENERGY.
# DOPE score               : -24569.697266
# >> Normalized DOPE z score: -0.751
# readlinef__W> File: FM_0.B99990006.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945    1945
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   380212
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -24401.1094
#
#
#
#
# << end of ENERGY.
# DOPE score               : -24401.109375
# >> Normalized DOPE z score: -0.707
# readlinef__W> File: FM_0.B99990005.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945    1945
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   379880
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -24366.9434
#
#
#
#
# << end of ENERGY.
# DOPE score               : -24366.943359
# >> Normalized DOPE z score: -0.698
# readlinef__W> File: FM_0.B99990004.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945    1945
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   380008
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -24504.5449
#
#
#
#
# << end of ENERGY.
# DOPE score               : -24504.544922
# >> Normalized DOPE z score: -0.734
# readlinef__W> File: FM_0.B99990003.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945    1945
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   381101
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -24356.0605
#
#
#
#
# << end of ENERGY.
# DOPE score               : -24356.060547
# >> Normalized DOPE z score: -0.695
# readlinef__W> File: FM_0.B99990010.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945    1945
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   380345
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -24420.2715
#
#
#
#
# << end of ENERGY.
# DOPE score               : -24420.271484
# >> Normalized DOPE z score: -0.712
# readlinef__W> File: FM_0.B99990009.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945    1945
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   381044
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -24082.2070
#
#
#
#
# << end of ENERGY.
# DOPE score               : -24082.207031
# >> Normalized DOPE z score: -0.623
# readlinef__W> File: FM_0.B99990007.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945    1945
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   380436
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -24254.5449
#
#
#
#
# << end of ENERGY.
# DOPE score               : -24254.544922
# >> Normalized DOPE z score: -0.668
# readlinef__W> File: FM_0.B99990008.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  VAL:OXT  VAL
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      270
# Number of all, selected real atoms                :     1945    1945
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   379942
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -24372.9512
#
#
#
#
# << end of ENERGY.
# DOPE score               : -24372.951172
# >> Normalized DOPE z score: -0.699
#                 Model  DOPE Score
# 0  FM_0.B99990001.pdb   -0.765481
# 1  FM_0.B99990002.pdb   -0.751088
# 4  FM_0.B99990004.pdb   -0.733999
# 6  FM_0.B99990010.pdb   -0.711893
# 2  FM_0.B99990006.pdb   -0.706867
# 9  FM_0.B99990008.pdb   -0.699481
# 3  FM_0.B99990005.pdb   -0.697905
# 5  FM_0.B99990003.pdb   -0.695051
# 8  FM_0.B99990007.pdb   -0.668423
# 7  FM_0.B99990009.pdb   -0.623219

# %% [markdown]
# Verify the modelled side-chains using tools such as:
# - PROCHECK
# - Verify3D
# - WHATCHECK
#
# Some are available at https://saves.mbi.ucla.edu/.
